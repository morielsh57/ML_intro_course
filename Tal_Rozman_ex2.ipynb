# %% [markdown]
# Student 1: name: Moriel Tomchin, i.d.: 206970063, github: https://github.com/morielsh57/ML_intro_course
#
# Student 2: Tal Rozman: , i.d.: 211680178, github: https://github.com/TalRozman/ML_intro_course
#
# Student 3: Emma Hrinevitzky : , i.d.: 206385858 , github: https://github.com/emmahr1998/ML_intro_course

# %% [markdown]
# Libraries (don't change)

# %%
# !pip -q install torchinfo

from dataclasses import dataclass
from typing import List, Callable, Optional, Tuple

import numpy as np
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms
from torchinfo import summary

from sklearn.metrics import confusion_matrix, classification_report

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Device (don't change)

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
use_amp = (DEVICE == "cuda")

print(f"Using device: {DEVICE}")
print(f"Mixed precision (AMP): {use_amp}")
# Out:
# Using device: cpu
# Mixed precision (AMP): False

# %% [markdown]
# Data (don't change)

# %%
class DataManager:
    def __init__(self, dataset_class, root: str = "./data", val_fraction: float = 0.1,
                 batch_size: int = 32, seed: int = 42):
        self.dataset_class = dataset_class
        self.root = root
        self.val_fraction = val_fraction
        self.batch_size = batch_size
        self.seed = seed

        self.transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.1918,), (0.3483,))
        ])

    def get_loaders(self) -> Tuple[DataLoader, DataLoader, DataLoader]:
        full_train = self.dataset_class(root=self.root, train=True,
                                        download=True, transform=self.transform)
        test_ds = self.dataset_class(root=self.root, train=False,
                                     download=True, transform=self.transform)

        val_size = int(len(full_train) * self.val_fraction)
        train_size = len(full_train) - val_size

        generator = torch.Generator().manual_seed(self.seed)
        train_ds, val_ds = random_split(full_train, [train_size, val_size], generator=generator)

        train_loader = DataLoader(train_ds, batch_size=self.batch_size,
                                  shuffle=True, num_workers=2, pin_memory=True)
        val_loader   = DataLoader(val_ds,   batch_size=self.batch_size,
                                  shuffle=False, num_workers=2, pin_memory=True)
        test_loader  = DataLoader(test_ds,  batch_size=self.batch_size,
                                  shuffle=False, num_workers=2, pin_memory=True)

        print(f"Train: {len(train_ds)} | Val: {len(val_ds)} | Test: {len(test_ds)}")
        return train_loader, val_loader, test_loader

# %% [markdown]
# Configurations (don't change)

# %%
@dataclass
class LayerSpec:
    out_dim: int
    activation: Callable[[torch.Tensor], torch.Tensor] = F.relu
    dropout: float = 0.0
    batch_norm: bool = True
    weight_decay: float = 0.0

@dataclass
class ModelConfig:
    input_dim: Tuple[int, int, int] = (1, 28, 28)
    num_classes: int = 10
    layers: List[LayerSpec] = None

@dataclass
class TrainConfig:
    batch_size: int = 64
    epochs: int = 100
    lr: float = 1e-4
    patience: int = 15
    min_delta: float = 1e-4
    val_fraction: float = 0.1
    seed: int = 42

# %% [markdown]
# Model

# %%
class MLPFromConfig(nn.Module):
    def __init__(self, config: ModelConfig):
        super().__init__()
        flat_dim = config.input_dim[0] * config.input_dim[1] * config.input_dim[2]
        self.layers_specs = config.layers
        layers = []
        prev_dim = flat_dim

        for i, spec in enumerate(config.layers):
            linear = nn.Linear(prev_dim, spec.out_dim)

            layers.append(linear)
            if spec.batch_norm:
                layers.append(nn.BatchNorm1d(spec.out_dim))
            if spec.dropout > 0:
                layers.append(nn.Dropout(spec.dropout))
            layers.append(spec.activation())
            prev_dim = spec.out_dim

        # Final classifier layer
        self.final_linear = nn.Linear(prev_dim, config.num_classes)
        layers.append(self.final_linear)

        self.net = nn.Sequential(*layers)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = x.view(x.size(0), -1)
        return self.net(x)

    def get_layer_params(self):
        param_groups = []
        for i, spec in enumerate(self.layers_specs):
            linear_layer = self.net[i * (4 if spec.batch_norm or spec.dropout > 0 else 3)]
            pass
        return self.layers_specs

# %% [markdown]
# Early Stopping (don't change)

# %%
class EarlyStopping:
    def __init__(self, patience: int = 10, min_delta: float = 1e-4):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = float('inf')
        self.should_stop = False

    def __call__(self, val_loss: float) -> bool:
        if val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.should_stop = True
        return self.should_stop

# %% [markdown]
# Trainer (don't change)

# %%
class Trainer:
    def __init__(self, model: nn.Module, config: TrainConfig):
        self.model = model.to(DEVICE)
        self.config = config
        self.criterion = nn.CrossEntropyLoss()
        self.optimizer = self._build_optimizer()
        self.scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
        self.early_stopping = EarlyStopping(patience=config.patience,
                                            min_delta=config.min_delta)

        self.history = {"train_loss": [], "train_acc": [],
                        "val_loss": [], "val_acc": []}

    def _build_optimizer(self):

        # Collect all Linear layers in the order they appear
        linear_layers = []
        for name, module in self.model.named_modules():
            if isinstance(module, nn.Linear):
                linear_layers.append((name, module))

        param_groups = []

        for i, spec in enumerate(self.model.layers_specs):
            name, layer = linear_layers[i]
            param_groups.append({
                'params': layer.parameters(),
                'weight_decay': spec.weight_decay
            })

        final_name, final_layer = linear_layers[-1]
        param_groups.append({
            'params': final_layer.parameters(),
            'weight_decay': 0.0
        })

        return torch.optim.SGD(param_groups, momentum=0.9, nesterov=True, lr=self.config.lr)

    def _train_epoch(self, loader: DataLoader):
        self.model.train()
        total_loss = 0.0
        correct = 0
        total = 0

        for data, target in loader:
            data, target = data.to(DEVICE), target.to(DEVICE)

            self.optimizer.zero_grad()
            with torch.cuda.amp.autocast(enabled=use_amp):
                output = self.model(data)
                loss = self.criterion(output, target)

            self.scaler.scale(loss).backward()
            self.scaler.step(self.optimizer)
            self.scaler.update()

            total_loss += loss.item() * data.size(0)
            correct += (output.argmax(1) == target).sum().item()
            total += data.size(0)

        return total_loss / total, correct / total

    @torch.no_grad()
    def _eval_epoch(self, loader: DataLoader):
        self.model.eval()
        total_loss = 0.0
        correct = 0
        total = 0

        for data, target in loader:
            data, target = data.to(DEVICE), target.to(DEVICE)
            with torch.cuda.amp.autocast(enabled=use_amp):
                output = self.model(data)
                loss = self.criterion(output, target)

            total_loss += loss.item() * data.size(0)
            correct += (output.argmax(1) == target).sum().item()
            total += data.size(0)

        return total_loss / total, correct / total

    def fit(self, train_loader: DataLoader, val_loader: DataLoader):
        print("🚀 Starting training...\n")
        for epoch in range(1, self.config.epochs + 1):
            train_loss, train_acc = self._train_epoch(train_loader)
            val_loss, val_acc     = self._eval_epoch(val_loader)

            self.history["train_loss"].append(train_loss)
            self.history["train_acc"].append(train_acc)
            self.history["val_loss"].append(val_loss)
            self.history["val_acc"].append(val_acc)

            print(f"Epoch {epoch:3d} | "
                  f"Train Loss: {train_loss:.4f} Acc: {train_acc:.4f} | "
                  f"Val Loss: {val_loss:.4f} Acc: {val_acc:.4f}")

            if self.early_stopping(val_loss):
                print(f"\n🛑 Early stopping triggered at epoch {epoch}")
                break

        print("\n✅ Training complete!")

    @torch.no_grad()
    def evaluate(self, loader: DataLoader):
        return self._eval_epoch(loader)

    @torch.no_grad()
    def predict_all(self, loader: DataLoader):
        self.model.eval()
        all_preds, all_targets = [], []
        for x, y in loader:
            x = x.to(DEVICE, non_blocking=True)
            logits = self.model(x)
            preds = logits.argmax(dim=1).cpu().numpy()
            all_preds.append(preds)
            all_targets.append(y.numpy())
        return np.concatenate(all_preds), np.concatenate(all_targets)


    def save(self, path: str = "mlp_best.pt"):
        torch.save(self.model.state_dict(), path)
        print(f"💾 Model saved to {path}")

# %% [markdown]
# Run (do change)

# %%
# !pip -q install mlflow

import mlflow
import pandas as pd
from sklearn.metrics import precision_recall_fscore_support
import os
from google.colab import files

def calculate_metrics(trainer, loader, prefix):
    preds, targets = trainer.predict_all(loader)

    precision, recall, f1, _ = precision_recall_fscore_support(
        targets, preds, average='macro', zero_division=0
    )

    return {
        f"{prefix}_Precision": precision,
        f"{prefix}_Recall": recall,
        f"{prefix}_F1": f1
    }

def run_experiment(exp_name, train_cfg, model_cfg,run_name=None):
    mlflow.set_experiment(exp_name)
    timestamp = time.strftime("%Y%m%d-%H%M%S")
    run_name = run_name or f"Run_{timestamp}"

    data_mgr = DataManager(
        dataset_class=datasets.KMNIST,
        val_fraction=train_cfg.val_fraction,
        batch_size=train_cfg.batch_size,
        seed=train_cfg.seed
    )
    train_loader, val_loader, test_loader = data_mgr.get_loaders()

    # Build model
    model = MLPFromConfig(model_cfg)
    trainer = Trainer(model, train_cfg)
    print(summary(model, input_size=(1, 28, 28)))

    with mlflow.start_run(run_name=run_name):
        params_to_log = {
                "epochs": train_cfg.epochs,
                "batch_size": train_cfg.batch_size,
                "lr": train_cfg.lr,
                "seed": train_cfg.seed,
                "optimizer": "SGD",
                "layers_count": len(model_cfg.layers)
            }
        mlflow.log_params(params_to_log)

        trainer.fit(train_loader, val_loader)
        model_filename = f"{run_name}_model.pt"
        trainer.save(model_filename)

        if os.path.exists(model_filename):
            print(f"Uploading {model_filename} to MLflow...")
            mlflow.log_artifact(model_filename)
        else:
            print(f"⚠️ Error: Could not find {model_filename}, skipping upload.")

        mlflow.log_params(params_to_log)
        train_metrics = calculate_metrics(trainer, train_loader, "Train")
        test_metrics = calculate_metrics(trainer, test_loader, "Test")
        all_metrics = {**train_metrics, **test_metrics}
        mlflow.log_metrics(all_metrics)
        mlflow.log_artifact(f"{run_name}_model.pt")

        excel_row = {"Run_Name": run_name}
        excel_row.update(params_to_log)
        excel_row.update(all_metrics)
        return {"data":excel_row,"trainer":trainer,"test_loader":test_loader}


experiments_data = []

cfg_1 = TrainConfig(
    batch_size=128,
    epochs=100,
    lr=1e-2,
    patience=5,
    val_fraction=0.1)
model_cfg_1 = ModelConfig(layers=[
    LayerSpec(out_dim=1024, dropout=0.2, activation=nn.ReLU, weight_decay=1e-5),
    LayerSpec(out_dim=512, dropout=0.2, activation=nn.ReLU, weight_decay=1e-5),
    LayerSpec(out_dim=256, dropout=0.2, activation=nn.ReLU, weight_decay=1e-5)
])
experiments_data.append(run_experiment("KMNIST_Final_HW", cfg_1, model_cfg_1, "Exp_1"))


cfg_2 = TrainConfig(
    batch_size=128,
    epochs=100,
    lr=1e-4,
    patience=5,
    val_fraction=0.1)
model_cfg_2 = ModelConfig(layers=[
    LayerSpec(out_dim=512, dropout=0.2, batch_norm=True, activation=nn.ReLU, weight_decay=1e-5),
    LayerSpec(out_dim=256,  dropout=0.4, batch_norm=True, activation=nn.ReLU, weight_decay=1e-4),
    LayerSpec(out_dim=128, batch_norm=True, activation = nn.ReLU, weight_decay=5e-1),
])
experiments_data.append(run_experiment("KMNIST_Final_HW", cfg_2, model_cfg_2, "Exp_2"))


cfg_3 = TrainConfig(
    batch_size=128,
    epochs=100,
    lr=1e-4,
    patience=5,
    val_fraction=0.1)
model_cfg_3 = ModelConfig(layers=[
    LayerSpec(out_dim=128, dropout=0.2, batch_norm=True, activation=nn.ReLU, weight_decay=1e-3),
    LayerSpec(out_dim=64,  dropout=0.1, batch_norm=False, activation=nn.ReLU, weight_decay=1e-4),
    LayerSpec(out_dim=10,  dropout=0.1, batch_norm=False, activation = nn.ReLU, weight_decay=5e-1),
])
experiments_data.append(run_experiment("KMNIST_Final_HW", cfg_3, model_cfg_3, "Exp_3"))


cfg_4 = TrainConfig(
    batch_size=128,
    epochs=100,
    lr=1e-4,
    patience=5,
    val_fraction=0.1)
model_cfg_4 = ModelConfig(layers=[
    LayerSpec(out_dim=1024, dropout=0.5, batch_norm=True, activation=nn.ReLU, weight_decay=1e-4),
    LayerSpec(out_dim=1024, dropout=0.5, batch_norm=True, activation=nn.ReLU, weight_decay=1e-4),
    LayerSpec(out_dim=512, dropout=0.2, batch_norm=True, activation=nn.ReLU, weight_decay=1e-4),
    LayerSpec(out_dim=256, dropout=0.1, batch_norm=True, activation=nn.ReLU),
])
experiments_data.append(run_experiment("KMNIST_Final_HW", cfg_4, model_cfg_4, "Exp_4"))


cfg_5 = TrainConfig(
    batch_size=128,
    epochs=100,
    lr= 1e-3,
    patience= 15,
    val_fraction=0.1)
model_cfg_5 = ModelConfig(layers=[
    LayerSpec(out_dim=1024, dropout=0.3, batch_norm=True, activation=nn.ReLU, weight_decay=1e-5),
    LayerSpec(out_dim=1024, dropout=0.3, batch_norm=True, activation=nn.ReLU, weight_decay=1e-5),
    LayerSpec(out_dim=512, dropout=0.2, batch_norm=True, activation=nn.ReLU, weight_decay=1e-6),
    LayerSpec(out_dim=256, dropout=0.1, batch_norm=True, activation=nn.ReLU),
])
experiments_data.append(run_experiment("KMNIST_Final_HW", cfg_5, model_cfg_5, "Exp_5"))


cfg_6 = TrainConfig(
    batch_size=128,
    epochs=100,
    lr= 1e-2,
    patience= 15,
    val_fraction=0.1)
model_cfg_6 = ModelConfig(layers=[
    LayerSpec(out_dim=1024, dropout=0.4, batch_norm=True, activation=nn.ReLU, weight_decay=1e-5),
    LayerSpec(out_dim=1024, dropout=0.4, batch_norm=True, activation=nn.ReLU, weight_decay=1e-5),
    LayerSpec(out_dim=512, dropout=0.2, batch_norm=True, activation=nn.ReLU, weight_decay=1e-5),
    LayerSpec(out_dim=256, dropout=0.0, batch_norm=True, activation=nn.ReLU),
])
experiments_data.append(run_experiment("KMNIST_Final_HW", cfg_6, model_cfg_6, "Exp_6"))


cfg_7 = TrainConfig(
    batch_size=128,
    epochs=100,
    lr= 5e-3,
    patience= 15,
    val_fraction=0.1)
model_cfg_7 = ModelConfig(layers=[
    LayerSpec(out_dim=1024, dropout=0.4, batch_norm=True, activation=nn.ReLU, weight_decay=1e-5),
    LayerSpec(out_dim=1024, dropout=0.4, batch_norm=True, activation=nn.ReLU, weight_decay=1e-5),
    LayerSpec(out_dim=512, dropout=0.2, batch_norm=True, activation=nn.ReLU, weight_decay=1e-5),
    LayerSpec(out_dim=256, dropout=0.0, batch_norm=True, activation=nn.ReLU),
])
experiments_data.append(run_experiment("KMNIST_Final_HW", cfg_7, model_cfg_7, "Exp_7"))


cfg_8 = TrainConfig(
    batch_size=128,
    epochs=100,
    lr= 7e-3,
    patience= 15,
    val_fraction=0.1)
model_cfg_8 = ModelConfig(layers=[
    LayerSpec(out_dim=1024, dropout=0.5, batch_norm=True, activation=nn.ReLU, weight_decay=5e-4),
    LayerSpec(out_dim=1024, dropout=0.5, batch_norm=True, activation=nn.ReLU, weight_decay=5e-4),
    LayerSpec(out_dim=512, dropout=0.3, batch_norm=True, activation=nn.ReLU, weight_decay=5e-4),
    LayerSpec(out_dim=256, dropout=0.1, batch_norm=True, activation=nn.ReLU),
])
experiments_data.append(run_experiment("KMNIST_Final_HW", cfg_8, model_cfg_8, "Exp_8"))


cfg_9 = TrainConfig(
    batch_size=128,
    epochs=100,
    patience= 15,
    lr=1e-3,
    val_fraction=0.1)
model_cfg_9 = ModelConfig(layers=[
    LayerSpec(out_dim=1024, dropout=0.5, batch_norm=True, activation=nn.ReLU, weight_decay=1e-4),
    LayerSpec(out_dim=1024, dropout=0.4, batch_norm=True, activation=nn.ReLU, weight_decay=1e-4),
    LayerSpec(out_dim=512, dropout=0.2, batch_norm=True, activation=nn.ReLU, weight_decay=1e-4),
    LayerSpec(out_dim=256, dropout=0.0, batch_norm=True, activation=nn.ReLU),
])
experiments_data.append(run_experiment("KMNIST_Final_HW", cfg_9, model_cfg_9, "Exp_9"))


cfg_10 = TrainConfig(
    batch_size=128,
    epochs=100,
    lr=1e-3,
    patience=7,
    val_fraction=0.1)
model_cfg_10 = ModelConfig(layers=[
    LayerSpec(out_dim=512, dropout=0.3, batch_norm=True,  activation=nn.ReLU, weight_decay=1e-4),
    LayerSpec(out_dim=256, dropout=0.2, batch_norm=True,  activation=nn.ReLU, weight_decay=1e-4),
    LayerSpec(out_dim=128, dropout=0.1, batch_norm=False, activation=nn.ReLU, weight_decay=1e-4),
])
experiments_data.append(run_experiment("KMNIST_Final_HW", cfg_10, model_cfg_10, "Exp_10"))


cfg_11 = TrainConfig(
    batch_size=128,
    epochs=100,
    lr=1e-3,
    patience=7,
    val_fraction=0.1)
model_cfg_11 = ModelConfig(layers=[
    LayerSpec(out_dim=512, dropout=0.3, batch_norm=True,  activation=nn.ReLU, weight_decay=1e-4),
    LayerSpec(out_dim=256, dropout=0.2, batch_norm=True,  activation=nn.ReLU, weight_decay=1e-4),
    LayerSpec(out_dim=128, dropout=0.1, batch_norm=False, activation=nn.ReLU, weight_decay=1e-4),
    LayerSpec(out_dim=10,  dropout=0.0, batch_norm=False, activation=nn.ReLU, weight_decay=0.0),
])
experiments_data.append(run_experiment("KMNIST_Final_HW", cfg_11, model_cfg_11, "Exp_11"))


cfg_12 = TrainConfig(
    batch_size=128,
    epochs=100,
    lr=1e-3,
    patience=7,
    val_fraction=0.1)
model_cfg_12 = ModelConfig(layers=[
    LayerSpec(out_dim=512, dropout=0.3, batch_norm=True,  activation=nn.ReLU, weight_decay=1e-4),
    LayerSpec(out_dim=256, dropout=0.2, batch_norm=True,  activation=nn.ReLU, weight_decay=1e-4),
    LayerSpec(out_dim=128, dropout=0.1, batch_norm=True, activation=nn.ReLU, weight_decay=1e-4),
    LayerSpec(out_dim=10,  dropout=0.0, batch_norm=False, activation=nn.ReLU, weight_decay=0.0),
])
experiments_data.append(run_experiment("KMNIST_Final_HW", cfg_12, model_cfg_12, "Exp_12"))



df_results = pd.DataFrame([item["data"] for item in experiments_data])
cols = ['Run_Name', 'Train_F1', 'Test_F1', 'Train_Precision', 'Test_Precision', 'Train_Recall', 'Test_Recall']
cols += [c for c in df_results.columns if c not in cols]
df_results = df_results[cols]

output_file = "experiment_results.xlsx"
df_results.to_excel(output_file, index=False)
files.download(output_file)

print(f"\n💾 Excel file saved to: {output_file}")
df_results.head(15)
# Out:
# Train: 54000 | Val: 6000 | Test: 10000
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLPFromConfig                            [1, 10]                   --
# ├─Sequential: 1-1                        [1, 10]                   --
# │    └─Linear: 2-1                       [1, 1024]                 803,840
# │    └─BatchNorm1d: 2-2                  [1, 1024]                 2,048
# │    └─Dropout: 2-3                      [1, 1024]                 --
# │    └─ReLU: 2-4                         [1, 1024]                 --
# │    └─Linear: 2-5                       [1, 512]                  524,800
# │    └─BatchNorm1d: 2-6                  [1, 512]                  1,024
# │    └─Dropout: 2-7                      [1, 512]                  --
# │    └─ReLU: 2-8                         [1, 512]                  --
# │    └─Linear: 2-9                       [1, 256]                  131,328
# │    └─BatchNorm1d: 2-10                 [1, 256]                  512
# │    └─Dropout: 2-11                     [1, 256]                  --
# │    └─ReLU: 2-12                        [1, 256]                  --
# │    └─Linear: 2-13                      [1, 10]                   2,570
# ==========================================================================================
# Total params: 1,466,122
# Trainable params: 1,466,122
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 1.47
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.03
# Params size (MB): 5.86
# Estimated Total Size (MB): 5.90
# ==========================================================================================
# 🚀 Starting training...
# Epoch   1 | Train Loss: 0.4471 Acc: 0.8641 | Val Loss: 0.2024 Acc: 0.9368
# Epoch   2 | Train Loss: 0.1963 Acc: 0.9394 | Val Loss: 0.1552 Acc: 0.9522
# Epoch   3 | Train Loss: 0.1410 Acc: 0.9561 | Val Loss: 0.1388 Acc: 0.9560
# Epoch   4 | Train Loss: 0.1099 Acc: 0.9644 | Val Loss: 0.1310 Acc: 0.9590
# Epoch   5 | Train Loss: 0.0884 Acc: 0.9717 | Val Loss: 0.1179 Acc: 0.9665
# Epoch   6 | Train Loss: 0.0757 Acc: 0.9761 | Val Loss: 0.1200 Acc: 0.9633
# Epoch   7 | Train Loss: 0.0611 Acc: 0.9807 | Val Loss: 0.1201 Acc: 0.9638
# Epoch   8 | Train Loss: 0.0537 Acc: 0.9829 | Val Loss: 0.1182 Acc: 0.9650
# Epoch   9 | Train Loss: 0.0480 Acc: 0.9846 | Val Loss: 0.1179 Acc: 0.9655
# Epoch  10 | Train Loss: 0.0452 Acc: 0.9850 | Val Loss: 0.1197 Acc: 0.9665
#
# 🛑 Early stopping triggered at epoch 10
#
# ✅ Training complete!
# 💾 Model saved to Exp_1_model.pt
# Uploading Exp_1_model.pt to MLflow...
# Train: 54000 | Val: 6000 | Test: 10000
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLPFromConfig                            [1, 10]                   --
# ├─Sequential: 1-1                        [1, 10]                   --
# │    └─Linear: 2-1                       [1, 512]                  401,920
# │    └─BatchNorm1d: 2-2                  [1, 512]                  1,024
# │    └─Dropout: 2-3                      [1, 512]                  --
# │    └─ReLU: 2-4                         [1, 512]                  --
# │    └─Linear: 2-5                       [1, 256]                  131,328
# │    └─BatchNorm1d: 2-6                  [1, 256]                  512
# │    └─Dropout: 2-7                      [1, 256]                  --
# │    └─ReLU: 2-8                         [1, 256]                  --
# │    └─Linear: 2-9                       [1, 128]                  32,896
# │    └─BatchNorm1d: 2-10                 [1, 128]                  256
# │    └─ReLU: 2-11                        [1, 128]                  --
# │    └─Linear: 2-12                      [1, 10]                   1,290
# ==========================================================================================
# Total params: 569,226
# Trainable params: 569,226
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.57
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 2.28
# Estimated Total Size (MB): 2.29
# ==========================================================================================
# 🚀 Starting training...
# Epoch   1 | Train Loss: 2.1269 Acc: 0.2741 | Val Loss: 1.8469 Acc: 0.5953
# Epoch   2 | Train Loss: 1.7239 Acc: 0.5475 | Val Loss: 1.4846 Acc: 0.6918
# Epoch   3 | Train Loss: 1.4403 Acc: 0.6485 | Val Loss: 1.2438 Acc: 0.7268
# Epoch   4 | Train Loss: 1.2279 Acc: 0.7001 | Val Loss: 1.0571 Acc: 0.7600
# Epoch   5 | Train Loss: 1.0683 Acc: 0.7357 | Val Loss: 0.9127 Acc: 0.7827
# Epoch   6 | Train Loss: 0.9414 Acc: 0.7647 | Val Loss: 0.7974 Acc: 0.8092
# Epoch   7 | Train Loss: 0.8341 Acc: 0.7920 | Val Loss: 0.7005 Acc: 0.8313
# Epoch   8 | Train Loss: 0.7435 Acc: 0.8124 | Val Loss: 0.6192 Acc: 0.8473
# Epoch   9 | Train Loss: 0.6688 Acc: 0.8309 | Val Loss: 0.5514 Acc: 0.8630
# Epoch  10 | Train Loss: 0.6060 Acc: 0.8457 | Val Loss: 0.4976 Acc: 0.8758
# Epoch  11 | Train Loss: 0.5532 Acc: 0.8589 | Val Loss: 0.4481 Acc: 0.8867
# Epoch  12 | Train Loss: 0.5100 Acc: 0.8673 | Val Loss: 0.4113 Acc: 0.8957
# Epoch  13 | Train Loss: 0.4752 Acc: 0.8747 | Val Loss: 0.3818 Acc: 0.9012
# Epoch  14 | Train Loss: 0.4465 Acc: 0.8833 | Val Loss: 0.3570 Acc: 0.9048
# Epoch  15 | Train Loss: 0.4251 Acc: 0.8887 | Val Loss: 0.3420 Acc: 0.9113
# Epoch  16 | Train Loss: 0.4067 Acc: 0.8924 | Val Loss: 0.3238 Acc: 0.9145
# Epoch  17 | Train Loss: 0.3908 Acc: 0.8970 | Val Loss: 0.3161 Acc: 0.9163
# Epoch  18 | Train Loss: 0.3799 Acc: 0.8985 | Val Loss: 0.3023 Acc: 0.9193
# Epoch  19 | Train Loss: 0.3739 Acc: 0.8986 | Val Loss: 0.2938 Acc: 0.9215
# Epoch  20 | Train Loss: 0.3562 Acc: 0.9042 | Val Loss: 0.2855 Acc: 0.9253
# Epoch  21 | Train Loss: 0.3507 Acc: 0.9062 | Val Loss: 0.2767 Acc: 0.9265
# Epoch  22 | Train Loss: 0.3415 Acc: 0.9066 | Val Loss: 0.2729 Acc: 0.9262
# Epoch  23 | Train Loss: 0.3336 Acc: 0.9103 | Val Loss: 0.2644 Acc: 0.9252
# Epoch  24 | Train Loss: 0.3243 Acc: 0.9118 | Val Loss: 0.2566 Acc: 0.9282
# Epoch  25 | Train Loss: 0.3212 Acc: 0.9116 | Val Loss: 0.2536 Acc: 0.9310
# Epoch  26 | Train Loss: 0.3147 Acc: 0.9138 | Val Loss: 0.2471 Acc: 0.9315
# Epoch  27 | Train Loss: 0.3042 Acc: 0.9161 | Val Loss: 0.2407 Acc: 0.9322
# Epoch  28 | Train Loss: 0.2973 Acc: 0.9185 | Val Loss: 0.2396 Acc: 0.9318
# Epoch  29 | Train Loss: 0.2964 Acc: 0.9183 | Val Loss: 0.2371 Acc: 0.9333
# Epoch  30 | Train Loss: 0.2911 Acc: 0.9188 | Val Loss: 0.2318 Acc: 0.9385
# Epoch  31 | Train Loss: 0.2844 Acc: 0.9209 | Val Loss: 0.2280 Acc: 0.9347
# Epoch  32 | Train Loss: 0.2823 Acc: 0.9212 | Val Loss: 0.2230 Acc: 0.9357
# Epoch  33 | Train Loss: 0.2762 Acc: 0.9224 | Val Loss: 0.2195 Acc: 0.9388
# Epoch  34 | Train Loss: 0.2726 Acc: 0.9237 | Val Loss: 0.2178 Acc: 0.9382
# Epoch  35 | Train Loss: 0.2680 Acc: 0.9250 | Val Loss: 0.2159 Acc: 0.9400
# Epoch  36 | Train Loss: 0.2626 Acc: 0.9259 | Val Loss: 0.2111 Acc: 0.9392
# Epoch  37 | Train Loss: 0.2578 Acc: 0.9270 | Val Loss: 0.2098 Acc: 0.9388
# Epoch  38 | Train Loss: 0.2563 Acc: 0.9269 | Val Loss: 0.2088 Acc: 0.9400
# Epoch  39 | Train Loss: 0.2536 Acc: 0.9281 | Val Loss: 0.2065 Acc: 0.9407
# Epoch  40 | Train Loss: 0.2509 Acc: 0.9290 | Val Loss: 0.2021 Acc: 0.9392
# Epoch  41 | Train Loss: 0.2465 Acc: 0.9311 | Val Loss: 0.2029 Acc: 0.9423
# Epoch  42 | Train Loss: 0.2442 Acc: 0.9303 | Val Loss: 0.2014 Acc: 0.9408
# Epoch  43 | Train Loss: 0.2411 Acc: 0.9327 | Val Loss: 0.2010 Acc: 0.9425
# Epoch  44 | Train Loss: 0.2383 Acc: 0.9317 | Val Loss: 0.1957 Acc: 0.9423
# Epoch  45 | Train Loss: 0.2352 Acc: 0.9323 | Val Loss: 0.1943 Acc: 0.9415
# Epoch  46 | Train Loss: 0.2292 Acc: 0.9349 | Val Loss: 0.1919 Acc: 0.9428
# Epoch  47 | Train Loss: 0.2298 Acc: 0.9349 | Val Loss: 0.1921 Acc: 0.9447
# Epoch  48 | Train Loss: 0.2286 Acc: 0.9340 | Val Loss: 0.1965 Acc: 0.9425
# Epoch  49 | Train Loss: 0.2236 Acc: 0.9357 | Val Loss: 0.1855 Acc: 0.9450
# Epoch  50 | Train Loss: 0.2237 Acc: 0.9352 | Val Loss: 0.1847 Acc: 0.9465
# Epoch  51 | Train Loss: 0.2176 Acc: 0.9385 | Val Loss: 0.1850 Acc: 0.9453
# Epoch  52 | Train Loss: 0.2180 Acc: 0.9366 | Val Loss: 0.1874 Acc: 0.9437
# Epoch  53 | Train Loss: 0.2162 Acc: 0.9375 | Val Loss: 0.1840 Acc: 0.9455
# Epoch  54 | Train Loss: 0.2127 Acc: 0.9391 | Val Loss: 0.1846 Acc: 0.9425
# Epoch  55 | Train Loss: 0.2115 Acc: 0.9386 | Val Loss: 0.1830 Acc: 0.9452
# Epoch  56 | Train Loss: 0.2083 Acc: 0.9394 | Val Loss: 0.1793 Acc: 0.9475
# Epoch  57 | Train Loss: 0.2082 Acc: 0.9396 | Val Loss: 0.1783 Acc: 0.9463
# Epoch  58 | Train Loss: 0.2082 Acc: 0.9395 | Val Loss: 0.1788 Acc: 0.9472
# Epoch  59 | Train Loss: 0.2033 Acc: 0.9406 | Val Loss: 0.1739 Acc: 0.9492
# Epoch  60 | Train Loss: 0.2029 Acc: 0.9414 | Val Loss: 0.1746 Acc: 0.9483
# Epoch  61 | Train Loss: 0.2018 Acc: 0.9416 | Val Loss: 0.1751 Acc: 0.9475
# Epoch  62 | Train Loss: 0.1999 Acc: 0.9421 | Val Loss: 0.1715 Acc: 0.9487
# Epoch  63 | Train Loss: 0.1965 Acc: 0.9423 | Val Loss: 0.1749 Acc: 0.9473
# Epoch  64 | Train Loss: 0.1939 Acc: 0.9438 | Val Loss: 0.1738 Acc: 0.9478
# Epoch  65 | Train Loss: 0.1901 Acc: 0.9443 | Val Loss: 0.1683 Acc: 0.9498
# Epoch  66 | Train Loss: 0.1927 Acc: 0.9441 | Val Loss: 0.1691 Acc: 0.9500
# Epoch  67 | Train Loss: 0.1886 Acc: 0.9449 | Val Loss: 0.1688 Acc: 0.9497
# Epoch  68 | Train Loss: 0.1904 Acc: 0.9440 | Val Loss: 0.1647 Acc: 0.9508
# Epoch  69 | Train Loss: 0.1844 Acc: 0.9459 | Val Loss: 0.1669 Acc: 0.9487
# Epoch  70 | Train Loss: 0.1877 Acc: 0.9449 | Val Loss: 0.1677 Acc: 0.9490
# Epoch  71 | Train Loss: 0.1840 Acc: 0.9457 | Val Loss: 0.1655 Acc: 0.9503
# Epoch  72 | Train Loss: 0.1805 Acc: 0.9472 | Val Loss: 0.1650 Acc: 0.9507
# Epoch  73 | Train Loss: 0.1838 Acc: 0.9464 | Val Loss: 0.1624 Acc: 0.9507
# Epoch  74 | Train Loss: 0.1801 Acc: 0.9471 | Val Loss: 0.1636 Acc: 0.9490
# Epoch  75 | Train Loss: 0.1792 Acc: 0.9468 | Val Loss: 0.1671 Acc: 0.9487
# Epoch  76 | Train Loss: 0.1788 Acc: 0.9470 | Val Loss: 0.1616 Acc: 0.9508
# Epoch  77 | Train Loss: 0.1785 Acc: 0.9478 | Val Loss: 0.1606 Acc: 0.9495
# Epoch  78 | Train Loss: 0.1736 Acc: 0.9495 | Val Loss: 0.1590 Acc: 0.9507
# Epoch  79 | Train Loss: 0.1734 Acc: 0.9484 | Val Loss: 0.1581 Acc: 0.9515
# Epoch  80 | Train Loss: 0.1738 Acc: 0.9491 | Val Loss: 0.1580 Acc: 0.9518
# Epoch  81 | Train Loss: 0.1728 Acc: 0.9491 | Val Loss: 0.1573 Acc: 0.9500
# Epoch  82 | Train Loss: 0.1713 Acc: 0.9487 | Val Loss: 0.1583 Acc: 0.9503
# Epoch  83 | Train Loss: 0.1672 Acc: 0.9504 | Val Loss: 0.1555 Acc: 0.9523
# Epoch  84 | Train Loss: 0.1673 Acc: 0.9507 | Val Loss: 0.1589 Acc: 0.9533
# Epoch  85 | Train Loss: 0.1662 Acc: 0.9507 | Val Loss: 0.1546 Acc: 0.9522
# Epoch  86 | Train Loss: 0.1646 Acc: 0.9516 | Val Loss: 0.1580 Acc: 0.9513
# Epoch  87 | Train Loss: 0.1658 Acc: 0.9503 | Val Loss: 0.1535 Acc: 0.9527
# Epoch  88 | Train Loss: 0.1647 Acc: 0.9509 | Val Loss: 0.1515 Acc: 0.9528
# Epoch  89 | Train Loss: 0.1620 Acc: 0.9525 | Val Loss: 0.1486 Acc: 0.9543
# Epoch  90 | Train Loss: 0.1605 Acc: 0.9516 | Val Loss: 0.1543 Acc: 0.9527
# Epoch  91 | Train Loss: 0.1609 Acc: 0.9522 | Val Loss: 0.1516 Acc: 0.9528
# Epoch  92 | Train Loss: 0.1599 Acc: 0.9529 | Val Loss: 0.1494 Acc: 0.9530
# Epoch  93 | Train Loss: 0.1623 Acc: 0.9515 | Val Loss: 0.1533 Acc: 0.9535
# Epoch  94 | Train Loss: 0.1574 Acc: 0.9534 | Val Loss: 0.1539 Acc: 0.9520
#
# 🛑 Early stopping triggered at epoch 94
#
# ✅ Training complete!
# 💾 Model saved to Exp_2_model.pt
# Uploading Exp_2_model.pt to MLflow...
# Train: 54000 | Val: 6000 | Test: 10000
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLPFromConfig                            [1, 10]                   --
# ├─Sequential: 1-1                        [1, 10]                   --
# │    └─Linear: 2-1                       [1, 128]                  100,480
# │    └─BatchNorm1d: 2-2                  [1, 128]                  256
# │    └─Dropout: 2-3                      [1, 128]                  --
# │    └─ReLU: 2-4                         [1, 128]                  --
# │    └─Linear: 2-5                       [1, 64]                   8,256
# │    └─Dropout: 2-6                      [1, 64]                   --
# │    └─ReLU: 2-7                         [1, 64]                   --
# │    └─Linear: 2-8                       [1, 10]                   650
# │    └─Dropout: 2-9                      [1, 10]                   --
# │    └─ReLU: 2-10                        [1, 10]                   --
# │    └─Linear: 2-11                      [1, 10]                   110
# ==========================================================================================
# Total params: 109,752
# Trainable params: 109,752
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.11
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.44
# Estimated Total Size (MB): 0.44
# ==========================================================================================
# 🚀 Starting training...
# Epoch   1 | Train Loss: 2.3139 Acc: 0.1074 | Val Loss: 2.3009 Acc: 0.1033
# Epoch   2 | Train Loss: 2.2981 Acc: 0.1192 | Val Loss: 2.2882 Acc: 0.1228
# Epoch   3 | Train Loss: 2.2875 Acc: 0.1367 | Val Loss: 2.2791 Acc: 0.1498
# Epoch   4 | Train Loss: 2.2795 Acc: 0.1544 | Val Loss: 2.2710 Acc: 0.1752
# Epoch   5 | Train Loss: 2.2716 Acc: 0.1669 | Val Loss: 2.2634 Acc: 0.1865
# Epoch   6 | Train Loss: 2.2642 Acc: 0.1746 | Val Loss: 2.2552 Acc: 0.1940
# Epoch   7 | Train Loss: 2.2554 Acc: 0.1826 | Val Loss: 2.2459 Acc: 0.2000
# Epoch   8 | Train Loss: 2.2451 Acc: 0.1895 | Val Loss: 2.2347 Acc: 0.2072
# Epoch   9 | Train Loss: 2.2335 Acc: 0.1981 | Val Loss: 2.2225 Acc: 0.2135
# Epoch  10 | Train Loss: 2.2213 Acc: 0.2078 | Val Loss: 2.2087 Acc: 0.2262
# Epoch  11 | Train Loss: 2.2067 Acc: 0.2209 | Val Loss: 2.1926 Acc: 0.2442
# Epoch  12 | Train Loss: 2.1905 Acc: 0.2343 | Val Loss: 2.1753 Acc: 0.2588
# Epoch  13 | Train Loss: 2.1723 Acc: 0.2463 | Val Loss: 2.1545 Acc: 0.2722
# Epoch  14 | Train Loss: 2.1517 Acc: 0.2535 | Val Loss: 2.1319 Acc: 0.2790
# Epoch  15 | Train Loss: 2.1297 Acc: 0.2591 | Val Loss: 2.1079 Acc: 0.2823
# Epoch  16 | Train Loss: 2.1071 Acc: 0.2647 | Val Loss: 2.0830 Acc: 0.2837
# Epoch  17 | Train Loss: 2.0828 Acc: 0.2692 | Val Loss: 2.0559 Acc: 0.2867
# Epoch  18 | Train Loss: 2.0591 Acc: 0.2736 | Val Loss: 2.0299 Acc: 0.2845
# Epoch  19 | Train Loss: 2.0323 Acc: 0.2804 | Val Loss: 2.0036 Acc: 0.2905
# Epoch  20 | Train Loss: 2.0068 Acc: 0.2848 | Val Loss: 1.9759 Acc: 0.2940
# Epoch  21 | Train Loss: 1.9801 Acc: 0.2954 | Val Loss: 1.9460 Acc: 0.3122
# Epoch  22 | Train Loss: 1.9534 Acc: 0.3067 | Val Loss: 1.9172 Acc: 0.3255
# Epoch  23 | Train Loss: 1.9255 Acc: 0.3189 | Val Loss: 1.8887 Acc: 0.3463
# Epoch  24 | Train Loss: 1.8971 Acc: 0.3275 | Val Loss: 1.8552 Acc: 0.3615
# Epoch  25 | Train Loss: 1.8667 Acc: 0.3376 | Val Loss: 1.8230 Acc: 0.3703
# Epoch  26 | Train Loss: 1.8390 Acc: 0.3417 | Val Loss: 1.7890 Acc: 0.3805
# Epoch  27 | Train Loss: 1.8059 Acc: 0.3494 | Val Loss: 1.7539 Acc: 0.3885
# Epoch  28 | Train Loss: 1.7777 Acc: 0.3605 | Val Loss: 1.7207 Acc: 0.3948
# Epoch  29 | Train Loss: 1.7454 Acc: 0.3679 | Val Loss: 1.6880 Acc: 0.4055
# Epoch  30 | Train Loss: 1.7181 Acc: 0.3774 | Val Loss: 1.6524 Acc: 0.4197
# Epoch  31 | Train Loss: 1.6891 Acc: 0.3862 | Val Loss: 1.6267 Acc: 0.4382
# Epoch  32 | Train Loss: 1.6625 Acc: 0.3947 | Val Loss: 1.5958 Acc: 0.4568
# Epoch  33 | Train Loss: 1.6367 Acc: 0.4070 | Val Loss: 1.5634 Acc: 0.4753
# Epoch  34 | Train Loss: 1.6183 Acc: 0.4174 | Val Loss: 1.5421 Acc: 0.4927
# Epoch  35 | Train Loss: 1.5945 Acc: 0.4315 | Val Loss: 1.5202 Acc: 0.5122
# Epoch  36 | Train Loss: 1.5769 Acc: 0.4395 | Val Loss: 1.5022 Acc: 0.5293
# Epoch  37 | Train Loss: 1.5558 Acc: 0.4508 | Val Loss: 1.4786 Acc: 0.5443
# Epoch  38 | Train Loss: 1.5397 Acc: 0.4659 | Val Loss: 1.4600 Acc: 0.5605
# Epoch  39 | Train Loss: 1.5251 Acc: 0.4722 | Val Loss: 1.4442 Acc: 0.5770
# Epoch  40 | Train Loss: 1.5104 Acc: 0.4816 | Val Loss: 1.4254 Acc: 0.5857
# Epoch  41 | Train Loss: 1.4934 Acc: 0.4936 | Val Loss: 1.4096 Acc: 0.5980
# Epoch  42 | Train Loss: 1.4801 Acc: 0.4991 | Val Loss: 1.3904 Acc: 0.6073
# Epoch  43 | Train Loss: 1.4637 Acc: 0.5059 | Val Loss: 1.3797 Acc: 0.6198
# Epoch  44 | Train Loss: 1.4494 Acc: 0.5130 | Val Loss: 1.3599 Acc: 0.6248
# Epoch  45 | Train Loss: 1.4349 Acc: 0.5217 | Val Loss: 1.3412 Acc: 0.6300
# Epoch  46 | Train Loss: 1.4231 Acc: 0.5260 | Val Loss: 1.3315 Acc: 0.6382
# Epoch  47 | Train Loss: 1.4088 Acc: 0.5356 | Val Loss: 1.3123 Acc: 0.6442
# Epoch  48 | Train Loss: 1.3939 Acc: 0.5392 | Val Loss: 1.2975 Acc: 0.6462
# Epoch  49 | Train Loss: 1.3817 Acc: 0.5456 | Val Loss: 1.2830 Acc: 0.6517
# Epoch  50 | Train Loss: 1.3676 Acc: 0.5502 | Val Loss: 1.2652 Acc: 0.6625
# Epoch  51 | Train Loss: 1.3541 Acc: 0.5535 | Val Loss: 1.2531 Acc: 0.6672
# Epoch  52 | Train Loss: 1.3415 Acc: 0.5630 | Val Loss: 1.2357 Acc: 0.6738
# Epoch  53 | Train Loss: 1.3263 Acc: 0.5683 | Val Loss: 1.2179 Acc: 0.6770
# Epoch  54 | Train Loss: 1.3159 Acc: 0.5694 | Val Loss: 1.2042 Acc: 0.6852
# Epoch  55 | Train Loss: 1.3018 Acc: 0.5771 | Val Loss: 1.1964 Acc: 0.6908
# Epoch  56 | Train Loss: 1.2907 Acc: 0.5770 | Val Loss: 1.1763 Acc: 0.6948
# Epoch  57 | Train Loss: 1.2773 Acc: 0.5875 | Val Loss: 1.1661 Acc: 0.6968
# Epoch  58 | Train Loss: 1.2639 Acc: 0.5892 | Val Loss: 1.1501 Acc: 0.7008
# Epoch  59 | Train Loss: 1.2526 Acc: 0.5924 | Val Loss: 1.1345 Acc: 0.7072
# Epoch  60 | Train Loss: 1.2431 Acc: 0.5954 | Val Loss: 1.1219 Acc: 0.7085
# Epoch  61 | Train Loss: 1.2331 Acc: 0.5997 | Val Loss: 1.1111 Acc: 0.7140
# Epoch  62 | Train Loss: 1.2220 Acc: 0.6033 | Val Loss: 1.1012 Acc: 0.7177
# Epoch  63 | Train Loss: 1.2108 Acc: 0.6077 | Val Loss: 1.0883 Acc: 0.7208
# Epoch  64 | Train Loss: 1.1982 Acc: 0.6154 | Val Loss: 1.0790 Acc: 0.7255
# Epoch  65 | Train Loss: 1.1921 Acc: 0.6143 | Val Loss: 1.0658 Acc: 0.7308
# Epoch  66 | Train Loss: 1.1814 Acc: 0.6205 | Val Loss: 1.0551 Acc: 0.7312
# Epoch  67 | Train Loss: 1.1693 Acc: 0.6263 | Val Loss: 1.0433 Acc: 0.7367
# Epoch  68 | Train Loss: 1.1601 Acc: 0.6285 | Val Loss: 1.0332 Acc: 0.7422
# Epoch  69 | Train Loss: 1.1525 Acc: 0.6303 | Val Loss: 1.0222 Acc: 0.7445
# Epoch  70 | Train Loss: 1.1401 Acc: 0.6374 | Val Loss: 1.0158 Acc: 0.7472
# Epoch  71 | Train Loss: 1.1319 Acc: 0.6405 | Val Loss: 1.0034 Acc: 0.7503
# Epoch  72 | Train Loss: 1.1249 Acc: 0.6424 | Val Loss: 0.9937 Acc: 0.7530
# Epoch  73 | Train Loss: 1.1171 Acc: 0.6462 | Val Loss: 0.9812 Acc: 0.7560
# Epoch  74 | Train Loss: 1.1024 Acc: 0.6502 | Val Loss: 0.9709 Acc: 0.7545
# Epoch  75 | Train Loss: 1.0988 Acc: 0.6520 | Val Loss: 0.9640 Acc: 0.7578
# Epoch  76 | Train Loss: 1.0901 Acc: 0.6542 | Val Loss: 0.9538 Acc: 0.7582
# Epoch  77 | Train Loss: 1.0857 Acc: 0.6546 | Val Loss: 0.9449 Acc: 0.7608
# Epoch  78 | Train Loss: 1.0769 Acc: 0.6600 | Val Loss: 0.9372 Acc: 0.7637
# Epoch  79 | Train Loss: 1.0686 Acc: 0.6631 | Val Loss: 0.9297 Acc: 0.7668
# Epoch  80 | Train Loss: 1.0616 Acc: 0.6623 | Val Loss: 0.9220 Acc: 0.7673
# Epoch  81 | Train Loss: 1.0523 Acc: 0.6665 | Val Loss: 0.9129 Acc: 0.7692
# Epoch  82 | Train Loss: 1.0465 Acc: 0.6706 | Val Loss: 0.9032 Acc: 0.7708
# Epoch  83 | Train Loss: 1.0434 Acc: 0.6706 | Val Loss: 0.8948 Acc: 0.7730
# Epoch  84 | Train Loss: 1.0351 Acc: 0.6735 | Val Loss: 0.8881 Acc: 0.7742
# Epoch  85 | Train Loss: 1.0267 Acc: 0.6763 | Val Loss: 0.8812 Acc: 0.7762
# Epoch  86 | Train Loss: 1.0205 Acc: 0.6783 | Val Loss: 0.8744 Acc: 0.7778
# Epoch  87 | Train Loss: 1.0100 Acc: 0.6826 | Val Loss: 0.8653 Acc: 0.7782
# Epoch  88 | Train Loss: 1.0102 Acc: 0.6801 | Val Loss: 0.8650 Acc: 0.7802
# Epoch  89 | Train Loss: 1.0002 Acc: 0.6863 | Val Loss: 0.8541 Acc: 0.7812
# Epoch  90 | Train Loss: 0.9958 Acc: 0.6887 | Val Loss: 0.8434 Acc: 0.7830
# Epoch  91 | Train Loss: 0.9914 Acc: 0.6873 | Val Loss: 0.8395 Acc: 0.7842
# Epoch  92 | Train Loss: 0.9829 Acc: 0.6931 | Val Loss: 0.8336 Acc: 0.7868
# Epoch  93 | Train Loss: 0.9779 Acc: 0.6914 | Val Loss: 0.8278 Acc: 0.7877
# Epoch  94 | Train Loss: 0.9776 Acc: 0.6945 | Val Loss: 0.8239 Acc: 0.7888
# Epoch  95 | Train Loss: 0.9676 Acc: 0.6989 | Val Loss: 0.8144 Acc: 0.7897
# Epoch  96 | Train Loss: 0.9655 Acc: 0.6977 | Val Loss: 0.8102 Acc: 0.7922
# Epoch  97 | Train Loss: 0.9618 Acc: 0.6992 | Val Loss: 0.8051 Acc: 0.7935
# Epoch  98 | Train Loss: 0.9562 Acc: 0.7020 | Val Loss: 0.7988 Acc: 0.7940
# Epoch  99 | Train Loss: 0.9499 Acc: 0.7051 | Val Loss: 0.7951 Acc: 0.7948
# Epoch 100 | Train Loss: 0.9455 Acc: 0.7061 | Val Loss: 0.7883 Acc: 0.7970
#
# ✅ Training complete!
# 💾 Model saved to Exp_3_model.pt
# Uploading Exp_3_model.pt to MLflow...
# Train: 54000 | Val: 6000 | Test: 10000
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLPFromConfig                            [1, 10]                   --
# ├─Sequential: 1-1                        [1, 10]                   --
# │    └─Linear: 2-1                       [1, 1024]                 803,840
# │    └─BatchNorm1d: 2-2                  [1, 1024]                 2,048
# │    └─Dropout: 2-3                      [1, 1024]                 --
# │    └─ReLU: 2-4                         [1, 1024]                 --
# │    └─Linear: 2-5                       [1, 1024]                 1,049,600
# │    └─BatchNorm1d: 2-6                  [1, 1024]                 2,048
# │    └─Dropout: 2-7                      [1, 1024]                 --
# │    └─ReLU: 2-8                         [1, 1024]                 --
# │    └─Linear: 2-9                       [1, 512]                  524,800
# │    └─BatchNorm1d: 2-10                 [1, 512]                  1,024
# │    └─Dropout: 2-11                     [1, 512]                  --
# │    └─ReLU: 2-12                        [1, 512]                  --
# │    └─Linear: 2-13                      [1, 256]                  131,328
# │    └─BatchNorm1d: 2-14                 [1, 256]                  512
# │    └─Dropout: 2-15                     [1, 256]                  --
# │    └─ReLU: 2-16                        [1, 256]                  --
# │    └─Linear: 2-17                      [1, 10]                   2,570
# ==========================================================================================
# Total params: 2,517,770
# Trainable params: 2,517,770
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 2.52
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.05
# Params size (MB): 10.07
# Estimated Total Size (MB): 10.12
# ==========================================================================================
# 🚀 Starting training...
# Epoch   1 | Train Loss: 2.2515 Acc: 0.1712 | Val Loss: 2.0711 Acc: 0.4825
# Epoch   2 | Train Loss: 2.0165 Acc: 0.3440 | Val Loss: 1.8077 Acc: 0.6043
# Epoch   3 | Train Loss: 1.7701 Acc: 0.4790 | Val Loss: 1.5425 Acc: 0.6528
# Epoch   4 | Train Loss: 1.5424 Acc: 0.5644 | Val Loss: 1.3006 Acc: 0.6880
# Epoch   5 | Train Loss: 1.3583 Acc: 0.6174 | Val Loss: 1.1287 Acc: 0.7097
# Epoch   6 | Train Loss: 1.2159 Acc: 0.6533 | Val Loss: 0.9990 Acc: 0.7290
# Epoch   7 | Train Loss: 1.1084 Acc: 0.6797 | Val Loss: 0.8971 Acc: 0.7482
# Epoch   8 | Train Loss: 1.0217 Acc: 0.7014 | Val Loss: 0.8151 Acc: 0.7620
# Epoch   9 | Train Loss: 0.9570 Acc: 0.7157 | Val Loss: 0.7636 Acc: 0.7717
# Epoch  10 | Train Loss: 0.9020 Acc: 0.7301 | Val Loss: 0.7087 Acc: 0.7838
# Epoch  11 | Train Loss: 0.8570 Acc: 0.7420 | Val Loss: 0.6689 Acc: 0.7935
# Epoch  12 | Train Loss: 0.8175 Acc: 0.7522 | Val Loss: 0.6410 Acc: 0.8008
# Epoch  13 | Train Loss: 0.7844 Acc: 0.7607 | Val Loss: 0.6095 Acc: 0.8093
# Epoch  14 | Train Loss: 0.7517 Acc: 0.7709 | Val Loss: 0.5781 Acc: 0.8192
# Epoch  15 | Train Loss: 0.7275 Acc: 0.7763 | Val Loss: 0.5655 Acc: 0.8223
# Epoch  16 | Train Loss: 0.7059 Acc: 0.7830 | Val Loss: 0.5410 Acc: 0.8328
# Epoch  17 | Train Loss: 0.6821 Acc: 0.7904 | Val Loss: 0.5183 Acc: 0.8370
# Epoch  18 | Train Loss: 0.6660 Acc: 0.7937 | Val Loss: 0.5073 Acc: 0.8403
# Epoch  19 | Train Loss: 0.6502 Acc: 0.8002 | Val Loss: 0.4955 Acc: 0.8447
# Epoch  20 | Train Loss: 0.6363 Acc: 0.8039 | Val Loss: 0.4814 Acc: 0.8480
# Epoch  21 | Train Loss: 0.6217 Acc: 0.8078 | Val Loss: 0.4741 Acc: 0.8505
# Epoch  22 | Train Loss: 0.6042 Acc: 0.8136 | Val Loss: 0.4645 Acc: 0.8533
# Epoch  23 | Train Loss: 0.5938 Acc: 0.8165 | Val Loss: 0.4535 Acc: 0.8552
# Epoch  24 | Train Loss: 0.5790 Acc: 0.8188 | Val Loss: 0.4412 Acc: 0.8607
# Epoch  25 | Train Loss: 0.5776 Acc: 0.8202 | Val Loss: 0.4342 Acc: 0.8627
# Epoch  26 | Train Loss: 0.5644 Acc: 0.8256 | Val Loss: 0.4240 Acc: 0.8650
# Epoch  27 | Train Loss: 0.5518 Acc: 0.8275 | Val Loss: 0.4172 Acc: 0.8678
# Epoch  28 | Train Loss: 0.5413 Acc: 0.8309 | Val Loss: 0.4064 Acc: 0.8700
# Epoch  29 | Train Loss: 0.5341 Acc: 0.8331 | Val Loss: 0.4013 Acc: 0.8717
# Epoch  30 | Train Loss: 0.5262 Acc: 0.8372 | Val Loss: 0.3943 Acc: 0.8747
# Epoch  31 | Train Loss: 0.5199 Acc: 0.8381 | Val Loss: 0.3854 Acc: 0.8760
# Epoch  32 | Train Loss: 0.5151 Acc: 0.8385 | Val Loss: 0.3814 Acc: 0.8783
# Epoch  33 | Train Loss: 0.5054 Acc: 0.8429 | Val Loss: 0.3749 Acc: 0.8803
# Epoch  34 | Train Loss: 0.5019 Acc: 0.8436 | Val Loss: 0.3746 Acc: 0.8822
# Epoch  35 | Train Loss: 0.4932 Acc: 0.8454 | Val Loss: 0.3685 Acc: 0.8830
# Epoch  36 | Train Loss: 0.4851 Acc: 0.8485 | Val Loss: 0.3680 Acc: 0.8838
# Epoch  37 | Train Loss: 0.4818 Acc: 0.8498 | Val Loss: 0.3573 Acc: 0.8888
# Epoch  38 | Train Loss: 0.4753 Acc: 0.8519 | Val Loss: 0.3503 Acc: 0.8905
# Epoch  39 | Train Loss: 0.4670 Acc: 0.8548 | Val Loss: 0.3454 Acc: 0.8915
# Epoch  40 | Train Loss: 0.4654 Acc: 0.8538 | Val Loss: 0.3521 Acc: 0.8910
# Epoch  41 | Train Loss: 0.4589 Acc: 0.8566 | Val Loss: 0.3441 Acc: 0.8928
# Epoch  42 | Train Loss: 0.4534 Acc: 0.8590 | Val Loss: 0.3377 Acc: 0.8958
# Epoch  43 | Train Loss: 0.4484 Acc: 0.8590 | Val Loss: 0.3369 Acc: 0.8962
# Epoch  44 | Train Loss: 0.4451 Acc: 0.8589 | Val Loss: 0.3307 Acc: 0.8982
# Epoch  45 | Train Loss: 0.4410 Acc: 0.8622 | Val Loss: 0.3285 Acc: 0.8985
# Epoch  46 | Train Loss: 0.4337 Acc: 0.8656 | Val Loss: 0.3266 Acc: 0.9003
# Epoch  47 | Train Loss: 0.4294 Acc: 0.8672 | Val Loss: 0.3213 Acc: 0.9015
# Epoch  48 | Train Loss: 0.4238 Acc: 0.8667 | Val Loss: 0.3144 Acc: 0.9042
# Epoch  49 | Train Loss: 0.4242 Acc: 0.8679 | Val Loss: 0.3121 Acc: 0.9033
# Epoch  50 | Train Loss: 0.4201 Acc: 0.8686 | Val Loss: 0.3147 Acc: 0.9038
# Epoch  51 | Train Loss: 0.4154 Acc: 0.8698 | Val Loss: 0.3120 Acc: 0.9060
# Epoch  52 | Train Loss: 0.4127 Acc: 0.8703 | Val Loss: 0.3073 Acc: 0.9072
# Epoch  53 | Train Loss: 0.4034 Acc: 0.8757 | Val Loss: 0.3056 Acc: 0.9078
# Epoch  54 | Train Loss: 0.4007 Acc: 0.8744 | Val Loss: 0.3095 Acc: 0.9073
# Epoch  55 | Train Loss: 0.3989 Acc: 0.8752 | Val Loss: 0.3026 Acc: 0.9083
# Epoch  56 | Train Loss: 0.4004 Acc: 0.8739 | Val Loss: 0.3010 Acc: 0.9080
# Epoch  57 | Train Loss: 0.3952 Acc: 0.8768 | Val Loss: 0.2944 Acc: 0.9100
# Epoch  58 | Train Loss: 0.3956 Acc: 0.8765 | Val Loss: 0.2925 Acc: 0.9093
# Epoch  59 | Train Loss: 0.3877 Acc: 0.8784 | Val Loss: 0.2948 Acc: 0.9098
# Epoch  60 | Train Loss: 0.3882 Acc: 0.8777 | Val Loss: 0.2905 Acc: 0.9108
# Epoch  61 | Train Loss: 0.3808 Acc: 0.8802 | Val Loss: 0.2916 Acc: 0.9105
# Epoch  62 | Train Loss: 0.3807 Acc: 0.8806 | Val Loss: 0.2816 Acc: 0.9118
# Epoch  63 | Train Loss: 0.3750 Acc: 0.8830 | Val Loss: 0.2841 Acc: 0.9108
# Epoch  64 | Train Loss: 0.3739 Acc: 0.8830 | Val Loss: 0.2858 Acc: 0.9108
# Epoch  65 | Train Loss: 0.3711 Acc: 0.8833 | Val Loss: 0.2784 Acc: 0.9122
# Epoch  66 | Train Loss: 0.3686 Acc: 0.8840 | Val Loss: 0.2790 Acc: 0.9135
# Epoch  67 | Train Loss: 0.3644 Acc: 0.8863 | Val Loss: 0.2731 Acc: 0.9148
# Epoch  68 | Train Loss: 0.3619 Acc: 0.8855 | Val Loss: 0.2764 Acc: 0.9135
# Epoch  69 | Train Loss: 0.3613 Acc: 0.8869 | Val Loss: 0.2749 Acc: 0.9142
# Epoch  70 | Train Loss: 0.3613 Acc: 0.8868 | Val Loss: 0.2696 Acc: 0.9155
# Epoch  71 | Train Loss: 0.3541 Acc: 0.8879 | Val Loss: 0.2731 Acc: 0.9153
# Epoch  72 | Train Loss: 0.3511 Acc: 0.8898 | Val Loss: 0.2728 Acc: 0.9150
# Epoch  73 | Train Loss: 0.3516 Acc: 0.8896 | Val Loss: 0.2658 Acc: 0.9163
# Epoch  74 | Train Loss: 0.3534 Acc: 0.8884 | Val Loss: 0.2626 Acc: 0.9177
# Epoch  75 | Train Loss: 0.3441 Acc: 0.8906 | Val Loss: 0.2668 Acc: 0.9162
# Epoch  76 | Train Loss: 0.3416 Acc: 0.8932 | Val Loss: 0.2622 Acc: 0.9178
# Epoch  77 | Train Loss: 0.3441 Acc: 0.8919 | Val Loss: 0.2626 Acc: 0.9170
# Epoch  78 | Train Loss: 0.3398 Acc: 0.8934 | Val Loss: 0.2597 Acc: 0.9170
# Epoch  79 | Train Loss: 0.3382 Acc: 0.8935 | Val Loss: 0.2576 Acc: 0.9198
# Epoch  80 | Train Loss: 0.3353 Acc: 0.8946 | Val Loss: 0.2584 Acc: 0.9197
# Epoch  81 | Train Loss: 0.3345 Acc: 0.8947 | Val Loss: 0.2546 Acc: 0.9208
# Epoch  82 | Train Loss: 0.3296 Acc: 0.8965 | Val Loss: 0.2514 Acc: 0.9232
# Epoch  83 | Train Loss: 0.3285 Acc: 0.8964 | Val Loss: 0.2574 Acc: 0.9205
# Epoch  84 | Train Loss: 0.3266 Acc: 0.8974 | Val Loss: 0.2531 Acc: 0.9210
# Epoch  85 | Train Loss: 0.3241 Acc: 0.8978 | Val Loss: 0.2557 Acc: 0.9192
# Epoch  86 | Train Loss: 0.3250 Acc: 0.8972 | Val Loss: 0.2483 Acc: 0.9232
# Epoch  87 | Train Loss: 0.3235 Acc: 0.8970 | Val Loss: 0.2447 Acc: 0.9250
# Epoch  88 | Train Loss: 0.3190 Acc: 0.9002 | Val Loss: 0.2475 Acc: 0.9232
# Epoch  89 | Train Loss: 0.3181 Acc: 0.9004 | Val Loss: 0.2487 Acc: 0.9227
# Epoch  90 | Train Loss: 0.3175 Acc: 0.8999 | Val Loss: 0.2442 Acc: 0.9248
# Epoch  91 | Train Loss: 0.3135 Acc: 0.9012 | Val Loss: 0.2455 Acc: 0.9237
# Epoch  92 | Train Loss: 0.3138 Acc: 0.9009 | Val Loss: 0.2462 Acc: 0.9238
# Epoch  93 | Train Loss: 0.3141 Acc: 0.9002 | Val Loss: 0.2388 Acc: 0.9268
# Epoch  94 | Train Loss: 0.3108 Acc: 0.9017 | Val Loss: 0.2384 Acc: 0.9265
# Epoch  95 | Train Loss: 0.3092 Acc: 0.9020 | Val Loss: 0.2357 Acc: 0.9265
# Epoch  96 | Train Loss: 0.3078 Acc: 0.9035 | Val Loss: 0.2352 Acc: 0.9288
# Epoch  97 | Train Loss: 0.3050 Acc: 0.9039 | Val Loss: 0.2379 Acc: 0.9275
# Epoch  98 | Train Loss: 0.3038 Acc: 0.9045 | Val Loss: 0.2375 Acc: 0.9263
# Epoch  99 | Train Loss: 0.3023 Acc: 0.9054 | Val Loss: 0.2329 Acc: 0.9285
# Epoch 100 | Train Loss: 0.3021 Acc: 0.9054 | Val Loss: 0.2333 Acc: 0.9292
#
# ✅ Training complete!
# 💾 Model saved to Exp_4_model.pt
# Uploading Exp_4_model.pt to MLflow...
# Train: 54000 | Val: 6000 | Test: 10000
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLPFromConfig                            [1, 10]                   --
# ├─Sequential: 1-1                        [1, 10]                   --
# │    └─Linear: 2-1                       [1, 1024]                 803,840
# │    └─BatchNorm1d: 2-2                  [1, 1024]                 2,048
# │    └─Dropout: 2-3                      [1, 1024]                 --
# │    └─ReLU: 2-4                         [1, 1024]                 --
# │    └─Linear: 2-5                       [1, 1024]                 1,049,600
# │    └─BatchNorm1d: 2-6                  [1, 1024]                 2,048
# │    └─Dropout: 2-7                      [1, 1024]                 --
# │    └─ReLU: 2-8                         [1, 1024]                 --
# │    └─Linear: 2-9                       [1, 512]                  524,800
# │    └─BatchNorm1d: 2-10                 [1, 512]                  1,024
# │    └─Dropout: 2-11                     [1, 512]                  --
# │    └─ReLU: 2-12                        [1, 512]                  --
# │    └─Linear: 2-13                      [1, 256]                  131,328
# │    └─BatchNorm1d: 2-14                 [1, 256]                  512
# │    └─Dropout: 2-15                     [1, 256]                  --
# │    └─ReLU: 2-16                        [1, 256]                  --
# │    └─Linear: 2-17                      [1, 10]                   2,570
# ==========================================================================================
# Total params: 2,517,770
# Trainable params: 2,517,770
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 2.52
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.05
# Params size (MB): 10.07
# Estimated Total Size (MB): 10.12
# ==========================================================================================
# 🚀 Starting training...
# Epoch   1 | Train Loss: 1.1462 Acc: 0.6656 | Val Loss: 0.5420 Acc: 0.8332
# Epoch   2 | Train Loss: 0.5448 Acc: 0.8378 | Val Loss: 0.3708 Acc: 0.8850
# Epoch   3 | Train Loss: 0.4147 Acc: 0.8735 | Val Loss: 0.2973 Acc: 0.9073
# Epoch   4 | Train Loss: 0.3494 Acc: 0.8938 | Val Loss: 0.2613 Acc: 0.9178
# Epoch   5 | Train Loss: 0.3063 Acc: 0.9063 | Val Loss: 0.2335 Acc: 0.9280
# Epoch   6 | Train Loss: 0.2729 Acc: 0.9166 | Val Loss: 0.2118 Acc: 0.9375
# Epoch   7 | Train Loss: 0.2484 Acc: 0.9238 | Val Loss: 0.2025 Acc: 0.9387
# Epoch   8 | Train Loss: 0.2267 Acc: 0.9298 | Val Loss: 0.1851 Acc: 0.9438
# Epoch   9 | Train Loss: 0.2092 Acc: 0.9353 | Val Loss: 0.1748 Acc: 0.9490
# Epoch  10 | Train Loss: 0.1937 Acc: 0.9404 | Val Loss: 0.1695 Acc: 0.9473
# Epoch  11 | Train Loss: 0.1831 Acc: 0.9431 | Val Loss: 0.1667 Acc: 0.9505
# Epoch  12 | Train Loss: 0.1741 Acc: 0.9463 | Val Loss: 0.1568 Acc: 0.9532
# Epoch  13 | Train Loss: 0.1614 Acc: 0.9497 | Val Loss: 0.1518 Acc: 0.9535
# Epoch  14 | Train Loss: 0.1522 Acc: 0.9533 | Val Loss: 0.1478 Acc: 0.9545
# Epoch  15 | Train Loss: 0.1445 Acc: 0.9545 | Val Loss: 0.1395 Acc: 0.9578
# Epoch  16 | Train Loss: 0.1353 Acc: 0.9582 | Val Loss: 0.1428 Acc: 0.9577
# Epoch  17 | Train Loss: 0.1289 Acc: 0.9592 | Val Loss: 0.1368 Acc: 0.9575
# Epoch  18 | Train Loss: 0.1251 Acc: 0.9615 | Val Loss: 0.1349 Acc: 0.9595
# Epoch  19 | Train Loss: 0.1178 Acc: 0.9633 | Val Loss: 0.1315 Acc: 0.9607
# Epoch  20 | Train Loss: 0.1119 Acc: 0.9649 | Val Loss: 0.1316 Acc: 0.9613
# Epoch  21 | Train Loss: 0.1060 Acc: 0.9665 | Val Loss: 0.1276 Acc: 0.9615
# Epoch  22 | Train Loss: 0.1041 Acc: 0.9674 | Val Loss: 0.1271 Acc: 0.9613
# Epoch  23 | Train Loss: 0.1003 Acc: 0.9688 | Val Loss: 0.1236 Acc: 0.9640
# Epoch  24 | Train Loss: 0.0952 Acc: 0.9702 | Val Loss: 0.1234 Acc: 0.9632
# Epoch  25 | Train Loss: 0.0931 Acc: 0.9698 | Val Loss: 0.1231 Acc: 0.9650
# Epoch  26 | Train Loss: 0.0896 Acc: 0.9711 | Val Loss: 0.1235 Acc: 0.9645
# Epoch  27 | Train Loss: 0.0854 Acc: 0.9726 | Val Loss: 0.1210 Acc: 0.9645
# Epoch  28 | Train Loss: 0.0837 Acc: 0.9731 | Val Loss: 0.1177 Acc: 0.9648
# Epoch  29 | Train Loss: 0.0809 Acc: 0.9741 | Val Loss: 0.1185 Acc: 0.9655
# Epoch  30 | Train Loss: 0.0759 Acc: 0.9755 | Val Loss: 0.1184 Acc: 0.9655
# Epoch  31 | Train Loss: 0.0742 Acc: 0.9765 | Val Loss: 0.1154 Acc: 0.9672
# Epoch  32 | Train Loss: 0.0715 Acc: 0.9769 | Val Loss: 0.1139 Acc: 0.9673
# Epoch  33 | Train Loss: 0.0683 Acc: 0.9784 | Val Loss: 0.1169 Acc: 0.9665
# Epoch  34 | Train Loss: 0.0674 Acc: 0.9782 | Val Loss: 0.1163 Acc: 0.9682
# Epoch  35 | Train Loss: 0.0638 Acc: 0.9797 | Val Loss: 0.1133 Acc: 0.9683
# Epoch  36 | Train Loss: 0.0607 Acc: 0.9809 | Val Loss: 0.1119 Acc: 0.9685
# Epoch  37 | Train Loss: 0.0614 Acc: 0.9803 | Val Loss: 0.1163 Acc: 0.9668
# Epoch  38 | Train Loss: 0.0575 Acc: 0.9812 | Val Loss: 0.1123 Acc: 0.9680
# Epoch  39 | Train Loss: 0.0591 Acc: 0.9809 | Val Loss: 0.1182 Acc: 0.9668
# Epoch  40 | Train Loss: 0.0565 Acc: 0.9820 | Val Loss: 0.1136 Acc: 0.9682
# Epoch  41 | Train Loss: 0.0556 Acc: 0.9825 | Val Loss: 0.1121 Acc: 0.9692
# Epoch  42 | Train Loss: 0.0532 Acc: 0.9828 | Val Loss: 0.1147 Acc: 0.9677
# Epoch  43 | Train Loss: 0.0516 Acc: 0.9837 | Val Loss: 0.1092 Acc: 0.9687
# Epoch  44 | Train Loss: 0.0511 Acc: 0.9832 | Val Loss: 0.1144 Acc: 0.9685
# Epoch  45 | Train Loss: 0.0498 Acc: 0.9843 | Val Loss: 0.1148 Acc: 0.9670
# Epoch  46 | Train Loss: 0.0467 Acc: 0.9849 | Val Loss: 0.1134 Acc: 0.9688
# Epoch  47 | Train Loss: 0.0457 Acc: 0.9861 | Val Loss: 0.1167 Acc: 0.9683
# Epoch  48 | Train Loss: 0.0439 Acc: 0.9858 | Val Loss: 0.1142 Acc: 0.9675
# Epoch  49 | Train Loss: 0.0428 Acc: 0.9865 | Val Loss: 0.1180 Acc: 0.9665
# Epoch  50 | Train Loss: 0.0430 Acc: 0.9866 | Val Loss: 0.1133 Acc: 0.9683
# Epoch  51 | Train Loss: 0.0441 Acc: 0.9856 | Val Loss: 0.1176 Acc: 0.9687
# Epoch  52 | Train Loss: 0.0413 Acc: 0.9862 | Val Loss: 0.1171 Acc: 0.9682
# Epoch  53 | Train Loss: 0.0407 Acc: 0.9869 | Val Loss: 0.1159 Acc: 0.9688
# Epoch  54 | Train Loss: 0.0413 Acc: 0.9866 | Val Loss: 0.1136 Acc: 0.9690
# Epoch  55 | Train Loss: 0.0369 Acc: 0.9885 | Val Loss: 0.1157 Acc: 0.9690
# Epoch  56 | Train Loss: 0.0369 Acc: 0.9885 | Val Loss: 0.1111 Acc: 0.9695
# Epoch  57 | Train Loss: 0.0353 Acc: 0.9888 | Val Loss: 0.1172 Acc: 0.9680
# Epoch  58 | Train Loss: 0.0370 Acc: 0.9877 | Val Loss: 0.1163 Acc: 0.9687
#
# 🛑 Early stopping triggered at epoch 58
#
# ✅ Training complete!
# 💾 Model saved to Exp_5_model.pt
# Uploading Exp_5_model.pt to MLflow...
# Train: 54000 | Val: 6000 | Test: 10000
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLPFromConfig                            [1, 10]                   --
# ├─Sequential: 1-1                        [1, 10]                   --
# │    └─Linear: 2-1                       [1, 1024]                 803,840
# │    └─BatchNorm1d: 2-2                  [1, 1024]                 2,048
# │    └─Dropout: 2-3                      [1, 1024]                 --
# │    └─ReLU: 2-4                         [1, 1024]                 --
# │    └─Linear: 2-5                       [1, 1024]                 1,049,600
# │    └─BatchNorm1d: 2-6                  [1, 1024]                 2,048
# │    └─Dropout: 2-7                      [1, 1024]                 --
# │    └─ReLU: 2-8                         [1, 1024]                 --
# │    └─Linear: 2-9                       [1, 512]                  524,800
# │    └─BatchNorm1d: 2-10                 [1, 512]                  1,024
# │    └─Dropout: 2-11                     [1, 512]                  --
# │    └─ReLU: 2-12                        [1, 512]                  --
# │    └─Linear: 2-13                      [1, 256]                  131,328
# │    └─BatchNorm1d: 2-14                 [1, 256]                  512
# │    └─ReLU: 2-15                        [1, 256]                  --
# │    └─Linear: 2-16                      [1, 10]                   2,570
# ==========================================================================================
# Total params: 2,517,770
# Trainable params: 2,517,770
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 2.52
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.05
# Params size (MB): 10.07
# Estimated Total Size (MB): 10.12
# ==========================================================================================
# 🚀 Starting training...
# Epoch   1 | Train Loss: 0.5611 Acc: 0.8233 | Val Loss: 0.2499 Acc: 0.9227
# Epoch   2 | Train Loss: 0.2727 Acc: 0.9142 | Val Loss: 0.1851 Acc: 0.9453
# Epoch   3 | Train Loss: 0.2144 Acc: 0.9328 | Val Loss: 0.1589 Acc: 0.9518
# Epoch   4 | Train Loss: 0.1801 Acc: 0.9427 | Val Loss: 0.1418 Acc: 0.9593
# Epoch   5 | Train Loss: 0.1565 Acc: 0.9503 | Val Loss: 0.1361 Acc: 0.9585
# Epoch   6 | Train Loss: 0.1380 Acc: 0.9567 | Val Loss: 0.1277 Acc: 0.9615
# Epoch   7 | Train Loss: 0.1238 Acc: 0.9603 | Val Loss: 0.1268 Acc: 0.9620
# Epoch   8 | Train Loss: 0.1147 Acc: 0.9631 | Val Loss: 0.1163 Acc: 0.9647
# Epoch   9 | Train Loss: 0.1052 Acc: 0.9666 | Val Loss: 0.1225 Acc: 0.9635
# Epoch  10 | Train Loss: 0.0941 Acc: 0.9691 | Val Loss: 0.1130 Acc: 0.9663
# Epoch  11 | Train Loss: 0.0923 Acc: 0.9703 | Val Loss: 0.1123 Acc: 0.9675
# Epoch  12 | Train Loss: 0.0786 Acc: 0.9746 | Val Loss: 0.1152 Acc: 0.9662
# Epoch  13 | Train Loss: 0.0771 Acc: 0.9746 | Val Loss: 0.1103 Acc: 0.9682
# Epoch  14 | Train Loss: 0.0692 Acc: 0.9772 | Val Loss: 0.1151 Acc: 0.9682
# Epoch  15 | Train Loss: 0.0697 Acc: 0.9773 | Val Loss: 0.1005 Acc: 0.9692
# Epoch  16 | Train Loss: 0.0621 Acc: 0.9801 | Val Loss: 0.1063 Acc: 0.9708
# Epoch  17 | Train Loss: 0.0615 Acc: 0.9788 | Val Loss: 0.1132 Acc: 0.9702
# Epoch  18 | Train Loss: 0.0564 Acc: 0.9816 | Val Loss: 0.1090 Acc: 0.9712
# Epoch  19 | Train Loss: 0.0561 Acc: 0.9809 | Val Loss: 0.1046 Acc: 0.9720
# Epoch  20 | Train Loss: 0.0534 Acc: 0.9825 | Val Loss: 0.1071 Acc: 0.9698
# Epoch  21 | Train Loss: 0.0498 Acc: 0.9832 | Val Loss: 0.1089 Acc: 0.9707
# Epoch  22 | Train Loss: 0.0491 Acc: 0.9831 | Val Loss: 0.1133 Acc: 0.9693
# Epoch  23 | Train Loss: 0.0466 Acc: 0.9842 | Val Loss: 0.1084 Acc: 0.9710
# Epoch  24 | Train Loss: 0.0443 Acc: 0.9850 | Val Loss: 0.1143 Acc: 0.9707
# Epoch  25 | Train Loss: 0.0409 Acc: 0.9863 | Val Loss: 0.1093 Acc: 0.9705
# Epoch  26 | Train Loss: 0.0392 Acc: 0.9869 | Val Loss: 0.1114 Acc: 0.9725
# Epoch  27 | Train Loss: 0.0401 Acc: 0.9866 | Val Loss: 0.1124 Acc: 0.9712
# Epoch  28 | Train Loss: 0.0355 Acc: 0.9879 | Val Loss: 0.1044 Acc: 0.9742
# Epoch  29 | Train Loss: 0.0371 Acc: 0.9876 | Val Loss: 0.1087 Acc: 0.9712
# Epoch  30 | Train Loss: 0.0350 Acc: 0.9874 | Val Loss: 0.1097 Acc: 0.9712
#
# 🛑 Early stopping triggered at epoch 30
#
# ✅ Training complete!
# 💾 Model saved to Exp_6_model.pt
# Uploading Exp_6_model.pt to MLflow...
# Train: 54000 | Val: 6000 | Test: 10000
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLPFromConfig                            [1, 10]                   --
# ├─Sequential: 1-1                        [1, 10]                   --
# │    └─Linear: 2-1                       [1, 1024]                 803,840
# │    └─BatchNorm1d: 2-2                  [1, 1024]                 2,048
# │    └─Dropout: 2-3                      [1, 1024]                 --
# │    └─ReLU: 2-4                         [1, 1024]                 --
# │    └─Linear: 2-5                       [1, 1024]                 1,049,600
# │    └─BatchNorm1d: 2-6                  [1, 1024]                 2,048
# │    └─Dropout: 2-7                      [1, 1024]                 --
# │    └─ReLU: 2-8                         [1, 1024]                 --
# │    └─Linear: 2-9                       [1, 512]                  524,800
# │    └─BatchNorm1d: 2-10                 [1, 512]                  1,024
# │    └─Dropout: 2-11                     [1, 512]                  --
# │    └─ReLU: 2-12                        [1, 512]                  --
# │    └─Linear: 2-13                      [1, 256]                  131,328
# │    └─BatchNorm1d: 2-14                 [1, 256]                  512
# │    └─ReLU: 2-15                        [1, 256]                  --
# │    └─Linear: 2-16                      [1, 10]                   2,570
# ==========================================================================================
# Total params: 2,517,770
# Trainable params: 2,517,770
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 2.52
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.05
# Params size (MB): 10.07
# Estimated Total Size (MB): 10.12
# ==========================================================================================
# 🚀 Starting training...
# Epoch   1 | Train Loss: 0.6989 Acc: 0.7823 | Val Loss: 0.2841 Acc: 0.9133
# Epoch   2 | Train Loss: 0.3273 Acc: 0.8965 | Val Loss: 0.2262 Acc: 0.9305
# Epoch   3 | Train Loss: 0.2565 Acc: 0.9198 | Val Loss: 0.1825 Acc: 0.9475
# Epoch   4 | Train Loss: 0.2126 Acc: 0.9323 | Val Loss: 0.1639 Acc: 0.9497
# Epoch   5 | Train Loss: 0.1850 Acc: 0.9430 | Val Loss: 0.1573 Acc: 0.9543
# Epoch   6 | Train Loss: 0.1639 Acc: 0.9489 | Val Loss: 0.1520 Acc: 0.9552
# Epoch   7 | Train Loss: 0.1495 Acc: 0.9522 | Val Loss: 0.1382 Acc: 0.9585
# Epoch   8 | Train Loss: 0.1402 Acc: 0.9567 | Val Loss: 0.1323 Acc: 0.9618
# Epoch   9 | Train Loss: 0.1274 Acc: 0.9584 | Val Loss: 0.1323 Acc: 0.9620
# Epoch  10 | Train Loss: 0.1148 Acc: 0.9631 | Val Loss: 0.1290 Acc: 0.9617
# Epoch  11 | Train Loss: 0.1069 Acc: 0.9657 | Val Loss: 0.1228 Acc: 0.9638
# Epoch  12 | Train Loss: 0.1014 Acc: 0.9675 | Val Loss: 0.1222 Acc: 0.9653
# Epoch  13 | Train Loss: 0.0952 Acc: 0.9690 | Val Loss: 0.1243 Acc: 0.9638
# Epoch  14 | Train Loss: 0.0886 Acc: 0.9710 | Val Loss: 0.1244 Acc: 0.9647
# Epoch  15 | Train Loss: 0.0859 Acc: 0.9720 | Val Loss: 0.1207 Acc: 0.9648
# Epoch  16 | Train Loss: 0.0796 Acc: 0.9739 | Val Loss: 0.1227 Acc: 0.9653
# Epoch  17 | Train Loss: 0.0769 Acc: 0.9753 | Val Loss: 0.1255 Acc: 0.9640
# Epoch  18 | Train Loss: 0.0727 Acc: 0.9764 | Val Loss: 0.1178 Acc: 0.9672
# Epoch  19 | Train Loss: 0.0671 Acc: 0.9777 | Val Loss: 0.1204 Acc: 0.9662
# Epoch  20 | Train Loss: 0.0643 Acc: 0.9791 | Val Loss: 0.1158 Acc: 0.9687
# Epoch  21 | Train Loss: 0.0609 Acc: 0.9803 | Val Loss: 0.1155 Acc: 0.9692
# Epoch  22 | Train Loss: 0.0585 Acc: 0.9809 | Val Loss: 0.1183 Acc: 0.9672
# Epoch  23 | Train Loss: 0.0580 Acc: 0.9805 | Val Loss: 0.1233 Acc: 0.9678
# Epoch  24 | Train Loss: 0.0523 Acc: 0.9828 | Val Loss: 0.1236 Acc: 0.9682
# Epoch  25 | Train Loss: 0.0528 Acc: 0.9823 | Val Loss: 0.1205 Acc: 0.9693
# Epoch  26 | Train Loss: 0.0481 Acc: 0.9838 | Val Loss: 0.1245 Acc: 0.9662
# Epoch  27 | Train Loss: 0.0486 Acc: 0.9836 | Val Loss: 0.1225 Acc: 0.9670
# Epoch  28 | Train Loss: 0.0462 Acc: 0.9846 | Val Loss: 0.1146 Acc: 0.9698
# Epoch  29 | Train Loss: 0.0455 Acc: 0.9849 | Val Loss: 0.1213 Acc: 0.9677
# Epoch  30 | Train Loss: 0.0417 Acc: 0.9857 | Val Loss: 0.1135 Acc: 0.9702
# Epoch  31 | Train Loss: 0.0430 Acc: 0.9854 | Val Loss: 0.1108 Acc: 0.9722
# Epoch  32 | Train Loss: 0.0423 Acc: 0.9856 | Val Loss: 0.1118 Acc: 0.9718
# Epoch  33 | Train Loss: 0.0403 Acc: 0.9863 | Val Loss: 0.1155 Acc: 0.9695
# Epoch  34 | Train Loss: 0.0385 Acc: 0.9869 | Val Loss: 0.1187 Acc: 0.9705
# Epoch  35 | Train Loss: 0.0379 Acc: 0.9874 | Val Loss: 0.1127 Acc: 0.9703
# Epoch  36 | Train Loss: 0.0356 Acc: 0.9881 | Val Loss: 0.1145 Acc: 0.9708
# Epoch  37 | Train Loss: 0.0360 Acc: 0.9883 | Val Loss: 0.1179 Acc: 0.9697
# Epoch  38 | Train Loss: 0.0352 Acc: 0.9881 | Val Loss: 0.1191 Acc: 0.9695
# Epoch  39 | Train Loss: 0.0331 Acc: 0.9887 | Val Loss: 0.1185 Acc: 0.9708
# Epoch  40 | Train Loss: 0.0313 Acc: 0.9894 | Val Loss: 0.1151 Acc: 0.9708
# Epoch  41 | Train Loss: 0.0314 Acc: 0.9900 | Val Loss: 0.1178 Acc: 0.9708
# Epoch  42 | Train Loss: 0.0314 Acc: 0.9892 | Val Loss: 0.1139 Acc: 0.9717
# Epoch  43 | Train Loss: 0.0331 Acc: 0.9887 | Val Loss: 0.1110 Acc: 0.9712
# Epoch  44 | Train Loss: 0.0292 Acc: 0.9899 | Val Loss: 0.1174 Acc: 0.9717
# Epoch  45 | Train Loss: 0.0295 Acc: 0.9900 | Val Loss: 0.1180 Acc: 0.9703
# Epoch  46 | Train Loss: 0.0277 Acc: 0.9912 | Val Loss: 0.1181 Acc: 0.9717
#
# 🛑 Early stopping triggered at epoch 46
#
# ✅ Training complete!
# 💾 Model saved to Exp_7_model.pt
# Uploading Exp_7_model.pt to MLflow...
# Train: 54000 | Val: 6000 | Test: 10000
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLPFromConfig                            [1, 10]                   --
# ├─Sequential: 1-1                        [1, 10]                   --
# │    └─Linear: 2-1                       [1, 1024]                 803,840
# │    └─BatchNorm1d: 2-2                  [1, 1024]                 2,048
# │    └─Dropout: 2-3                      [1, 1024]                 --
# ...
# Epoch  25 | Train Loss: 0.1318 Acc: 0.9584 | Val Loss: 0.1400 Acc: 0.9563
# Epoch  26 | Train Loss: 0.1272 Acc: 0.9600 | Val Loss: 0.1393 Acc: 0.9570
# Epoch  27 | Train Loss: 0.1269 Acc: 0.9602 | Val Loss: 0.1390 Acc: 0.9568
# Epoch  28 | Train Loss: 0.1234 Acc: 0.9597 | Val Loss: 0.1370 Acc: 0.9588
# Epoch  29 | Train Loss: 0.1190 Acc: 0.9612 | Val Loss: 0.1347 Acc: 0.9603
# Epoch  30 | Train Loss: 0.1138 Acc: 0.9633 | Val Loss: 0.1323 Acc: 0.9597
# Epoch  31 | Train Loss: 0.1090 Acc: 0.9651 | Val Loss: 0.1323 Acc: 0.9600
# Epoch  32 | Train Loss: 0.1104 Acc: 0.9646 | Val Loss: 0.1327 Acc: 0.9588
# Epoch  33 | Train Loss: 0.1028 Acc: 0.9671 | Val Loss: 0.1304 Acc: 0.9623
# Epoch  34 | Train Loss: 0.1015 Acc: 0.9676 | Val Loss: 0.1300 Acc: 0.9608
# Epoch  35 | Train Loss: 0.0992 Acc: 0.9691 | Val Loss: 0.1305 Acc: 0.9618
# Epoch  36 | Train Loss: 0.0993 Acc: 0.9687 | Val Loss: 0.1271 Acc: 0.9620
# Epoch  37 | Train Loss: 0.0940 Acc: 0.9698 | Val Loss: 0.1287 Acc: 0.9605
# Epoch  38 | Train Loss: 0.0947 Acc: 0.9695 | Val Loss: 0.1302 Acc: 0.9605
# Epoch  39 | Train Loss: 0.0905 Acc: 0.9706 | Val Loss: 0.1312 Acc: 0.9627
# Epoch  40 | Train Loss: 0.0888 Acc: 0.9714 | Val Loss: 0.1277 Acc: 0.9630
# Epoch  41 | Train Loss: 0.0861 Acc: 0.9722 | Val Loss: 0.1259 Acc: 0.9637
# Epoch  42 | Train Loss: 0.0872 Acc: 0.9715 | Val Loss: 0.1260 Acc: 0.9632
# Epoch  43 | Train Loss: 0.0830 Acc: 0.9725 | Val Loss: 0.1268 Acc: 0.9627
# Epoch  44 | Train Loss: 0.0803 Acc: 0.9739 | Val Loss: 0.1279 Acc: 0.9642
# Epoch  45 | Train Loss: 0.0813 Acc: 0.9738 | Val Loss: 0.1283 Acc: 0.9627
# Epoch  46 | Train Loss: 0.0783 Acc: 0.9740 | Val Loss: 0.1273 Acc: 0.9632
# Epoch  47 | Train Loss: 0.0750 Acc: 0.9758 | Val Loss: 0.1266 Acc: 0.9640
# Epoch  48 | Train Loss: 0.0749 Acc: 0.9758 | Val Loss: 0.1273 Acc: 0.9638
#
# 🛑 Early stopping triggered at epoch 48
#
# ✅ Training complete!
# 💾 Model saved to Exp_10_model.pt
# Uploading Exp_10_model.pt to MLflow...
# Train: 54000 | Val: 6000 | Test: 10000
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLPFromConfig                            [1, 10]                   --
# ├─Sequential: 1-1                        [1, 10]                   --
# │    └─Linear: 2-1                       [1, 512]                  401,920
# │    └─BatchNorm1d: 2-2                  [1, 512]                  1,024
# │    └─Dropout: 2-3                      [1, 512]                  --
# │    └─ReLU: 2-4                         [1, 512]                  --
# │    └─Linear: 2-5                       [1, 256]                  131,328
# │    └─BatchNorm1d: 2-6                  [1, 256]                  512
# │    └─Dropout: 2-7                      [1, 256]                  --
# │    └─ReLU: 2-8                         [1, 256]                  --
# │    └─Linear: 2-9                       [1, 128]                  32,896
# │    └─Dropout: 2-10                     [1, 128]                  --
# │    └─ReLU: 2-11                        [1, 128]                  --
# │    └─Linear: 2-12                      [1, 10]                   1,290
# │    └─ReLU: 2-13                        [1, 10]                   --
# │    └─Linear: 2-14                      [1, 10]                   110
# ==========================================================================================
# Total params: 569,080
# Trainable params: 569,080
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.57
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 2.28
# Estimated Total Size (MB): 2.29
# ==========================================================================================
# 🚀 Starting training...
# Epoch   1 | Train Loss: 2.1912 Acc: 0.2079 | Val Loss: 1.8892 Acc: 0.4293
# Epoch   2 | Train Loss: 1.4511 Acc: 0.5706 | Val Loss: 0.9769 Acc: 0.7420
# Epoch   3 | Train Loss: 0.8227 Acc: 0.7657 | Val Loss: 0.5815 Acc: 0.8323
# Epoch   4 | Train Loss: 0.5868 Acc: 0.8269 | Val Loss: 0.4388 Acc: 0.8750
# Epoch   5 | Train Loss: 0.4840 Acc: 0.8556 | Val Loss: 0.3688 Acc: 0.8948
# Epoch   6 | Train Loss: 0.4162 Acc: 0.8750 | Val Loss: 0.3230 Acc: 0.9057
# Epoch   7 | Train Loss: 0.3743 Acc: 0.8867 | Val Loss: 0.2924 Acc: 0.9160
# Epoch   8 | Train Loss: 0.3403 Acc: 0.8977 | Val Loss: 0.2667 Acc: 0.9213
# Epoch   9 | Train Loss: 0.3133 Acc: 0.9040 | Val Loss: 0.2497 Acc: 0.9273
# Epoch  10 | Train Loss: 0.2938 Acc: 0.9111 | Val Loss: 0.2358 Acc: 0.9315
# Epoch  11 | Train Loss: 0.2740 Acc: 0.9149 | Val Loss: 0.2219 Acc: 0.9365
# Epoch  12 | Train Loss: 0.2516 Acc: 0.9226 | Val Loss: 0.2132 Acc: 0.9385
# Epoch  13 | Train Loss: 0.2438 Acc: 0.9255 | Val Loss: 0.2024 Acc: 0.9437
# Epoch  14 | Train Loss: 0.2276 Acc: 0.9293 | Val Loss: 0.1970 Acc: 0.9428
# Epoch  15 | Train Loss: 0.2146 Acc: 0.9337 | Val Loss: 0.1906 Acc: 0.9438
# Epoch  16 | Train Loss: 0.2074 Acc: 0.9355 | Val Loss: 0.1844 Acc: 0.9483
# Epoch  17 | Train Loss: 0.1972 Acc: 0.9392 | Val Loss: 0.1792 Acc: 0.9480
# Epoch  18 | Train Loss: 0.1903 Acc: 0.9407 | Val Loss: 0.1767 Acc: 0.9490
# Epoch  19 | Train Loss: 0.1834 Acc: 0.9433 | Val Loss: 0.1748 Acc: 0.9497
# Epoch  20 | Train Loss: 0.1742 Acc: 0.9453 | Val Loss: 0.1711 Acc: 0.9505
# Epoch  21 | Train Loss: 0.1665 Acc: 0.9474 | Val Loss: 0.1675 Acc: 0.9517
# Epoch  22 | Train Loss: 0.1641 Acc: 0.9481 | Val Loss: 0.1663 Acc: 0.9517
# Epoch  23 | Train Loss: 0.1568 Acc: 0.9507 | Val Loss: 0.1624 Acc: 0.9527
# Epoch  24 | Train Loss: 0.1504 Acc: 0.9536 | Val Loss: 0.1585 Acc: 0.9542
# Epoch  25 | Train Loss: 0.1426 Acc: 0.9548 | Val Loss: 0.1593 Acc: 0.9545
# Epoch  26 | Train Loss: 0.1403 Acc: 0.9555 | Val Loss: 0.1553 Acc: 0.9557
# Epoch  27 | Train Loss: 0.1365 Acc: 0.9573 | Val Loss: 0.1538 Acc: 0.9548
# Epoch  28 | Train Loss: 0.1295 Acc: 0.9585 | Val Loss: 0.1516 Acc: 0.9558
# Epoch  29 | Train Loss: 0.1274 Acc: 0.9597 | Val Loss: 0.1532 Acc: 0.9560
# Epoch  30 | Train Loss: 0.1256 Acc: 0.9596 | Val Loss: 0.1500 Acc: 0.9568
# Epoch  31 | Train Loss: 0.1216 Acc: 0.9614 | Val Loss: 0.1511 Acc: 0.9565
# Epoch  32 | Train Loss: 0.1162 Acc: 0.9627 | Val Loss: 0.1506 Acc: 0.9567
# Epoch  33 | Train Loss: 0.1140 Acc: 0.9635 | Val Loss: 0.1494 Acc: 0.9567
# Epoch  34 | Train Loss: 0.1097 Acc: 0.9649 | Val Loss: 0.1460 Acc: 0.9578
# Epoch  35 | Train Loss: 0.1080 Acc: 0.9664 | Val Loss: 0.1463 Acc: 0.9588
# Epoch  36 | Train Loss: 0.1072 Acc: 0.9654 | Val Loss: 0.1453 Acc: 0.9590
# Epoch  37 | Train Loss: 0.1011 Acc: 0.9666 | Val Loss: 0.1461 Acc: 0.9580
# Epoch  38 | Train Loss: 0.0951 Acc: 0.9686 | Val Loss: 0.1432 Acc: 0.9595
# Epoch  39 | Train Loss: 0.0997 Acc: 0.9679 | Val Loss: 0.1434 Acc: 0.9578
# Epoch  40 | Train Loss: 0.0965 Acc: 0.9690 | Val Loss: 0.1437 Acc: 0.9582
# Epoch  41 | Train Loss: 0.0934 Acc: 0.9697 | Val Loss: 0.1406 Acc: 0.9590
# Epoch  42 | Train Loss: 0.0900 Acc: 0.9718 | Val Loss: 0.1460 Acc: 0.9590
# Epoch  43 | Train Loss: 0.0900 Acc: 0.9710 | Val Loss: 0.1367 Acc: 0.9625
# Epoch  44 | Train Loss: 0.0865 Acc: 0.9724 | Val Loss: 0.1406 Acc: 0.9603
# Epoch  45 | Train Loss: 0.0858 Acc: 0.9721 | Val Loss: 0.1376 Acc: 0.9595
# Epoch  46 | Train Loss: 0.0841 Acc: 0.9731 | Val Loss: 0.1427 Acc: 0.9608
# Epoch  47 | Train Loss: 0.0819 Acc: 0.9735 | Val Loss: 0.1392 Acc: 0.9608
# Epoch  48 | Train Loss: 0.0794 Acc: 0.9750 | Val Loss: 0.1424 Acc: 0.9605
# Epoch  49 | Train Loss: 0.0811 Acc: 0.9734 | Val Loss: 0.1389 Acc: 0.9612
# Epoch  50 | Train Loss: 0.0766 Acc: 0.9750 | Val Loss: 0.1422 Acc: 0.9612
#
# 🛑 Early stopping triggered at epoch 50
#
# ✅ Training complete!
# 💾 Model saved to Exp_11_model.pt
# Uploading Exp_11_model.pt to MLflow...
# Train: 54000 | Val: 6000 | Test: 10000
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLPFromConfig                            [1, 10]                   --
# ├─Sequential: 1-1                        [1, 10]                   --
# │    └─Linear: 2-1                       [1, 512]                  401,920
# │    └─BatchNorm1d: 2-2                  [1, 512]                  1,024
# │    └─Dropout: 2-3                      [1, 512]                  --
# │    └─ReLU: 2-4                         [1, 512]                  --
# │    └─Linear: 2-5                       [1, 256]                  131,328
# │    └─BatchNorm1d: 2-6                  [1, 256]                  512
# │    └─Dropout: 2-7                      [1, 256]                  --
# │    └─ReLU: 2-8                         [1, 256]                  --
# │    └─Linear: 2-9                       [1, 128]                  32,896
# │    └─BatchNorm1d: 2-10                 [1, 128]                  256
# │    └─Dropout: 2-11                     [1, 128]                  --
# │    └─ReLU: 2-12                        [1, 128]                  --
# │    └─Linear: 2-13                      [1, 10]                   1,290
# │    └─ReLU: 2-14                        [1, 10]                   --
# │    └─Linear: 2-15                      [1, 10]                   110
# ==========================================================================================
# Total params: 569,336
# Trainable params: 569,336
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.57
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 2.28
# Estimated Total Size (MB): 2.30
# ==========================================================================================
# 🚀 Starting training...
# Epoch   1 | Train Loss: 2.0278 Acc: 0.2923 | Val Loss: 1.4767 Acc: 0.6148
# Epoch   2 | Train Loss: 1.1254 Acc: 0.6972 | Val Loss: 0.7536 Acc: 0.8015
# Epoch   3 | Train Loss: 0.6967 Acc: 0.8050 | Val Loss: 0.5101 Acc: 0.8568
# Epoch   4 | Train Loss: 0.5332 Acc: 0.8460 | Val Loss: 0.3983 Acc: 0.8870
# Epoch   5 | Train Loss: 0.4442 Acc: 0.8701 | Val Loss: 0.3386 Acc: 0.9023
# Epoch   6 | Train Loss: 0.3895 Acc: 0.8853 | Val Loss: 0.3023 Acc: 0.9135
# Epoch   7 | Train Loss: 0.3471 Acc: 0.8964 | Val Loss: 0.2658 Acc: 0.9257
# Epoch   8 | Train Loss: 0.3169 Acc: 0.9056 | Val Loss: 0.2469 Acc: 0.9268
# Epoch   9 | Train Loss: 0.2892 Acc: 0.9120 | Val Loss: 0.2325 Acc: 0.9305
# Epoch  10 | Train Loss: 0.2696 Acc: 0.9191 | Val Loss: 0.2141 Acc: 0.9367
# Epoch  11 | Train Loss: 0.2526 Acc: 0.9229 | Val Loss: 0.2051 Acc: 0.9382
# Epoch  12 | Train Loss: 0.2371 Acc: 0.9276 | Val Loss: 0.1947 Acc: 0.9440
# Epoch  13 | Train Loss: 0.2265 Acc: 0.9303 | Val Loss: 0.1891 Acc: 0.9440
# Epoch  14 | Train Loss: 0.2115 Acc: 0.9343 | Val Loss: 0.1812 Acc: 0.9465
# Epoch  15 | Train Loss: 0.1996 Acc: 0.9381 | Val Loss: 0.1789 Acc: 0.9473
# Epoch  16 | Train Loss: 0.1916 Acc: 0.9401 | Val Loss: 0.1693 Acc: 0.9503
# Epoch  17 | Train Loss: 0.1841 Acc: 0.9436 | Val Loss: 0.1664 Acc: 0.9502
# Epoch  18 | Train Loss: 0.1754 Acc: 0.9458 | Val Loss: 0.1613 Acc: 0.9505
# Epoch  19 | Train Loss: 0.1692 Acc: 0.9478 | Val Loss: 0.1603 Acc: 0.9517
# Epoch  20 | Train Loss: 0.1634 Acc: 0.9503 | Val Loss: 0.1579 Acc: 0.9520
# Epoch  21 | Train Loss: 0.1572 Acc: 0.9505 | Val Loss: 0.1561 Acc: 0.9515
# Epoch  22 | Train Loss: 0.1525 Acc: 0.9512 | Val Loss: 0.1488 Acc: 0.9567
# Epoch  23 | Train Loss: 0.1435 Acc: 0.9558 | Val Loss: 0.1483 Acc: 0.9562
# Epoch  24 | Train Loss: 0.1400 Acc: 0.9560 | Val Loss: 0.1492 Acc: 0.9552
# Epoch  25 | Train Loss: 0.1384 Acc: 0.9564 | Val Loss: 0.1469 Acc: 0.9570
# Epoch  26 | Train Loss: 0.1311 Acc: 0.9583 | Val Loss: 0.1502 Acc: 0.9553
# Epoch  27 | Train Loss: 0.1288 Acc: 0.9592 | Val Loss: 0.1475 Acc: 0.9565
# Epoch  28 | Train Loss: 0.1232 Acc: 0.9612 | Val Loss: 0.1429 Acc: 0.9565
# Epoch  29 | Train Loss: 0.1198 Acc: 0.9618 | Val Loss: 0.1432 Acc: 0.9570
# Epoch  30 | Train Loss: 0.1151 Acc: 0.9636 | Val Loss: 0.1411 Acc: 0.9585
# Epoch  31 | Train Loss: 0.1115 Acc: 0.9649 | Val Loss: 0.1385 Acc: 0.9572
# Epoch  32 | Train Loss: 0.1104 Acc: 0.9647 | Val Loss: 0.1392 Acc: 0.9592
# Epoch  33 | Train Loss: 0.1102 Acc: 0.9648 | Val Loss: 0.1372 Acc: 0.9602
# Epoch  34 | Train Loss: 0.1076 Acc: 0.9657 | Val Loss: 0.1351 Acc: 0.9607
# Epoch  35 | Train Loss: 0.1006 Acc: 0.9683 | Val Loss: 0.1334 Acc: 0.9617
# Epoch  36 | Train Loss: 0.0989 Acc: 0.9685 | Val Loss: 0.1306 Acc: 0.9613
# Epoch  37 | Train Loss: 0.0948 Acc: 0.9696 | Val Loss: 0.1307 Acc: 0.9618
# Epoch  38 | Train Loss: 0.0960 Acc: 0.9694 | Val Loss: 0.1323 Acc: 0.9625
# Epoch  39 | Train Loss: 0.0926 Acc: 0.9703 | Val Loss: 0.1312 Acc: 0.9627
# Epoch  40 | Train Loss: 0.0900 Acc: 0.9711 | Val Loss: 0.1299 Acc: 0.9623
# Epoch  41 | Train Loss: 0.0867 Acc: 0.9711 | Val Loss: 0.1314 Acc: 0.9618
# Epoch  42 | Train Loss: 0.0848 Acc: 0.9735 | Val Loss: 0.1332 Acc: 0.9622
# Epoch  43 | Train Loss: 0.0839 Acc: 0.9734 | Val Loss: 0.1342 Acc: 0.9617
# Epoch  44 | Train Loss: 0.0843 Acc: 0.9724 | Val Loss: 0.1327 Acc: 0.9613
# Epoch  45 | Train Loss: 0.0812 Acc: 0.9731 | Val Loss: 0.1344 Acc: 0.9617
# Epoch  46 | Train Loss: 0.0798 Acc: 0.9747 | Val Loss: 0.1276 Acc: 0.9640
# Epoch  47 | Train Loss: 0.0787 Acc: 0.9745 | Val Loss: 0.1314 Acc: 0.9645
# Epoch  48 | Train Loss: 0.0753 Acc: 0.9758 | Val Loss: 0.1309 Acc: 0.9640
# Epoch  49 | Train Loss: 0.0752 Acc: 0.9755 | Val Loss: 0.1276 Acc: 0.9652
# Epoch  50 | Train Loss: 0.0722 Acc: 0.9767 | Val Loss: 0.1311 Acc: 0.9638
# Epoch  51 | Train Loss: 0.0721 Acc: 0.9765 | Val Loss: 0.1282 Acc: 0.9638
# Epoch  52 | Train Loss: 0.0696 Acc: 0.9775 | Val Loss: 0.1308 Acc: 0.9628
# Epoch  53 | Train Loss: 0.0686 Acc: 0.9776 | Val Loss: 0.1311 Acc: 0.9628
#
# 🛑 Early stopping triggered at epoch 53
#
# ✅ Training complete!
# 💾 Model saved to Exp_12_model.pt
# Uploading Exp_12_model.pt to MLflow...
# 💾 Excel file saved to: experiment_results.xlsx
#    Run_Name  Train_F1   Test_F1  Train_Precision  Test_Precision  \
# 0     Exp_1  0.998592  0.921413         0.998593        0.922542
# 1     Exp_2  0.983175  0.890451         0.983224        0.892361
# 2     Exp_3  0.812299  0.657210         0.813207        0.673298
# 3     Exp_4  0.946264  0.846777         0.947155        0.853608
# 4     Exp_5  0.999592  0.916144         0.999592        0.917963
# 5     Exp_6  0.999593  0.923845         0.999593        0.925215
# 6     Exp_7  0.999778  0.922929         0.999778        0.924727
# 7     Exp_8  0.999111  0.923825         0.999110        0.925301
# 8     Exp_9  0.998518  0.917754         0.998519        0.919810
# 9    Exp_10  0.997371  0.904771         0.997372        0.906298
# 10   Exp_11  0.997686  0.901345         0.997686        0.902965
# 11   Exp_12  0.997742  0.906639         0.997744        0.908872
#
#     Train_Recall  Test_Recall  epochs  batch_size      lr  seed optimizer  \
# 0       0.998594       0.9214     100         128  0.0100    42       SGD
# 1       0.983176       0.8903     100         128  0.0001    42       SGD
# 2       0.812451       0.6565     100         128  0.0001    42       SGD
# 3       0.946250       0.8464     100         128  0.0001    42       SGD
# 4       0.999592       0.9160     100         128  0.0010    42       SGD
# 5       0.999592       0.9237     100         128  0.0100    42       SGD
# 6       0.999778       0.9226     100         128  0.0050    42       SGD
# 7       0.999112       0.9237     100         128  0.0070    42       SGD
# 8       0.998520       0.9176     100         128  0.0010    42       SGD
# 9       0.997372       0.9047     100         128  0.0010    42       SGD
# 10      0.997688       0.9012     100         128  0.0010    42       SGD
# 11      0.997744       0.9064     100         128  0.0010    42       SGD
#
#     layers_count
# 0              3
# 1              3
# 2              3
# 3              4
# 4              4
# 5              4
# 6              4
# 7              4
# 8              4
# 9              3
# 10             4
# 11             4

# %% [markdown]
# Visuazize the train

# %%
for experiment in experiments_data:
  history = experiment["trainer"].history
  figure = plt.figure(figsize=(12, 4))
  figure.suptitle(experiment["data"]["Run_Name"])
  plt.subplot(1, 2, 1)
  plt.plot(history["train_loss"], label="Train Loss")
  plt.plot(history["val_loss"],   label="Val Loss")
  plt.title("Loss")
  plt.legend()
  plt.grid(True)

  plt.subplot(1, 2, 2)
  plt.plot(history["train_acc"], label="Train Acc")
  plt.plot(history["val_acc"],   label="Val Acc")
  plt.title("Accuracy")
  plt.legend()
  plt.grid(True)

  plt.tight_layout()
  plt.show()

# %% [markdown]
# Visualized the test (do change)

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# Define KMNIST Class Names
class_names = ['o', 'ki', 'su', 'tsu', 'na', 'ha', 'ma', 'ya', 're', 'wo']

for experiment in experiments_data:
    trainer = experiment["trainer"]
    test_loader = experiment["test_loader"]
    run_name = experiment["data"]["Run_Name"]

    print(f"\nExperiment: {run_name}")

    # Get predictions
    preds, targets = trainer.predict_all(test_loader)

    # Plot Confusion Matrix
    cm = confusion_matrix(targets, preds)
    
    plt.figure(figsize=(6, 6))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    
    # values_format='d' shows integers (counts) instead of scientific notation
    disp.plot(cmap='Blues', values_format='d', ax=plt.gca(), colorbar=True)
    
    plt.title(f"Confusion Matrix ({run_name})")
    plt.show()

    print(f"Classification report ({experiment["data"]["Run_Name"]}):")
    print(classification_report(targets, preds, digits=4))
# Out:
# Experiment: Exp_1
# Classification report (Exp_1):
#               precision    recall  f1-score   support
#
#            0     0.9261    0.9400    0.9330      1000
#            1     0.9333    0.9100    0.9215      1000
#            2     0.8788    0.8770    0.8779      1000
#            3     0.9200    0.9660    0.9424      1000
#            4     0.9214    0.9030    0.9121      1000
#            5     0.9759    0.8920    0.9321      1000
#            6     0.8753    0.9550    0.9134      1000
#            7     0.9376    0.9160    0.9267      1000
#            8     0.9073    0.9490    0.9277      1000
#            9     0.9497    0.9060    0.9273      1000
#
#     accuracy                         0.9214     10000
#    macro avg     0.9225    0.9214    0.9214     10000
# weighted avg     0.9225    0.9214    0.9214     10000
#
#
# Experiment: Exp_2
# Classification report (Exp_2):
#               precision    recall  f1-score   support
#
#            0     0.9130    0.9130    0.9130      1000
#            1     0.8804    0.8910    0.8857      1000
#            2     0.7970    0.8560    0.8255      1000
#            3     0.8992    0.9550    0.9263      1000
#            4     0.8856    0.8750    0.8803      1000
#            5     0.9639    0.8280    0.8908      1000
#            6     0.8771    0.9210    0.8985      1000
#            7     0.9318    0.8750    0.9025      1000
#            8     0.8749    0.9020    0.8882      1000
#            9     0.9005    0.8870    0.8937      1000
#
#     accuracy                         0.8903     10000
#    macro avg     0.8924    0.8903    0.8905     10000
# weighted avg     0.8924    0.8903    0.8905     10000
#
#
# Experiment: Exp_3
# Classification report (Exp_3):
#               precision    recall  f1-score   support
#
#            0     0.8068    0.8020    0.8044      1000
#            1     0.6310    0.6600    0.6452      1000
#            2     0.4811    0.5850    0.5280      1000
#            3     0.8125    0.7800    0.7959      1000
#            4     0.5852    0.6010    0.5930      1000
#            5     0.8099    0.6520    0.7224      1000
#            6     0.6473    0.7030    0.6740      1000
#            7     0.7235    0.4580    0.5609      1000
#            8     0.5348    0.7760    0.6332      1000
#            9     0.7008    0.5480    0.6150      1000
#
#     accuracy                         0.6565     10000
#    macro avg     0.6733    0.6565    0.6572     10000
# weighted avg     0.6733    0.6565    0.6572     10000
#
#
# Experiment: Exp_4
# Classification report (Exp_4):
#               precision    recall  f1-score   support
#
#            0     0.8918    0.8570    0.8740      1000
#            1     0.8454    0.8310    0.8381      1000
#            2     0.7657    0.8170    0.7905      1000
#            3     0.8762    0.9340    0.9042      1000
#            4     0.8944    0.7540    0.8182      1000
#            5     0.9531    0.7730    0.8537      1000
#            6     0.7914    0.9220    0.8517      1000
#            7     0.8874    0.8350    0.8604      1000
#            8     0.7349    0.8980    0.8083      1000
#            9     0.8959    0.8430    0.8686      1000
#
#     accuracy                         0.8464     10000
#    macro avg     0.8536    0.8464    0.8468     10000
# weighted avg     0.8536    0.8464    0.8468     10000
#
#
# Experiment: Exp_5
# Classification report (Exp_5):
#               precision    recall  f1-score   support
#
#            0     0.9408    0.9210    0.9308      1000
#            1     0.9270    0.9010    0.9138      1000
#            2     0.8514    0.8880    0.8693      1000
#            3     0.9132    0.9680    0.9398      1000
#            4     0.9232    0.8900    0.9063      1000
#            5     0.9854    0.8780    0.9286      1000
#            6     0.8779    0.9560    0.9153      1000
#            7     0.9356    0.9160    0.9257      1000
#            8     0.8788    0.9430    0.9098      1000
#            9     0.9463    0.8990    0.9221      1000
#
#     accuracy                         0.9160     10000
#    macro avg     0.9180    0.9160    0.9161     10000
# weighted avg     0.9180    0.9160    0.9161     10000
#
#
# Experiment: Exp_6
# Classification report (Exp_6):
#               precision    recall  f1-score   support
#
#            0     0.9567    0.9270    0.9416      1000
#            1     0.9273    0.9060    0.9165      1000
#            2     0.8745    0.8920    0.8832      1000
#            3     0.9281    0.9680    0.9476      1000
#            4     0.9220    0.9100    0.9160      1000
#            5     0.9772    0.8990    0.9365      1000
#            6     0.8779    0.9560    0.9153      1000
#            7     0.9460    0.9290    0.9374      1000
#            8     0.8860    0.9480    0.9159      1000
#            9     0.9565    0.9020    0.9285      1000
#
#     accuracy                         0.9237     10000
#    macro avg     0.9252    0.9237    0.9238     10000
# weighted avg     0.9252    0.9237    0.9238     10000
#
#
# Experiment: Exp_7
# Classification report (Exp_7):
#               precision    recall  f1-score   support
#
#            0     0.9556    0.9250    0.9400      1000
#            1     0.9458    0.9070    0.9260      1000
#            2     0.8239    0.9030    0.8616      1000
#            3     0.9437    0.9560    0.9498      1000
#            4     0.9441    0.8950    0.9189      1000
#            5     0.9641    0.8870    0.9240      1000
#            6     0.8912    0.9500    0.9197      1000
#            7     0.9527    0.9260    0.9391      1000
#            8     0.8916    0.9620    0.9254      1000
#            9     0.9346    0.9150    0.9247      1000
#
#     accuracy                         0.9226     10000
#    macro avg     0.9247    0.9226    0.9229     10000
# weighted avg     0.9247    0.9226    0.9229     10000
#
#
# Experiment: Exp_8
# Classification report (Exp_8):
#               precision    recall  f1-score   support
#
#            0     0.9349    0.9330    0.9339      1000
#            1     0.9396    0.9020    0.9204      1000
#            2     0.8781    0.8930    0.8855      1000
#            3     0.9149    0.9670    0.9402      1000
#            4     0.9257    0.9090    0.9173      1000
#            5     0.9759    0.8910    0.9315      1000
#            6     0.8648    0.9660    0.9126      1000
#            7     0.9545    0.9240    0.9390      1000
#            8     0.9094    0.9340    0.9216      1000
#            9     0.9553    0.9180    0.9363      1000
#
#     accuracy                         0.9237     10000
#    macro avg     0.9253    0.9237    0.9238     10000
# weighted avg     0.9253    0.9237    0.9238     10000
#
#
# Experiment: Exp_9
# Classification report (Exp_9):
#               precision    recall  f1-score   support
#
#            0     0.9355    0.9280    0.9317      1000
#            1     0.9324    0.8960    0.9138      1000
#            2     0.8661    0.8930    0.8794      1000
#            3     0.9373    0.9560    0.9465      1000
#            4     0.9239    0.8990    0.9113      1000
#            5     0.9820    0.8740    0.9249      1000
#            6     0.8627    0.9680    0.9123      1000
#            7     0.9469    0.9090    0.9276      1000
#            8     0.8717    0.9510    0.9096      1000
#            9     0.9396    0.9020    0.9204      1000
#
#     accuracy                         0.9176     10000
#    macro avg     0.9198    0.9176    0.9178     10000
# weighted avg     0.9198    0.9176    0.9178     10000
#
#
# Experiment: Exp_10
# Classification report (Exp_10):
#               precision    recall  f1-score   support
#
#            0     0.9232    0.9250    0.9241      1000
#            1     0.9240    0.8880    0.9057      1000
#            2     0.8499    0.8720    0.8608      1000
#            3     0.8953    0.9660    0.9293      1000
#            4     0.8810    0.8810    0.8810      1000
#            5     0.9568    0.8860    0.9200      1000
#            6     0.8669    0.9440    0.9038      1000
#            7     0.9455    0.8840    0.9137      1000
#            8     0.8813    0.9210    0.9007      1000
#            9     0.9392    0.8800    0.9086      1000
#
#     accuracy                         0.9047     10000
#    macro avg     0.9063    0.9047    0.9048     10000
# weighted avg     0.9063    0.9047    0.9048     10000
#
#
# Experiment: Exp_11
# Classification report (Exp_11):
#               precision    recall  f1-score   support
#
#            0     0.9364    0.9270    0.9317      1000
#            1     0.8988    0.8880    0.8934      1000
#            2     0.8543    0.8680    0.8611      1000
#            3     0.8996    0.9590    0.9284      1000
#            4     0.8606    0.8890    0.8746      1000
#            5     0.9658    0.8760    0.9187      1000
#            6     0.8562    0.9350    0.8939      1000
#            7     0.9428    0.8730    0.9065      1000
#            8     0.8857    0.9140    0.8996      1000
#            9     0.9295    0.8830    0.9056      1000
#
#     accuracy                         0.9012     10000
#    macro avg     0.9030    0.9012    0.9013     10000
# weighted avg     0.9030    0.9012    0.9013     10000
#
#
# Experiment: Exp_12
# Classification report (Exp_12):
#               precision    recall  f1-score   support
#
#            0     0.9474    0.9190    0.9330      1000
#            1     0.9117    0.8880    0.8997      1000
#            2     0.8485    0.8850    0.8664      1000
#            3     0.9171    0.9510    0.9337      1000
#            4     0.9006    0.8880    0.8943      1000
#            5     0.9626    0.8740    0.9161      1000
#            6     0.8346    0.9590    0.8925      1000
#            7     0.9453    0.8990    0.9216      1000
#            8     0.8822    0.9290    0.9050      1000
#            9     0.9386    0.8720    0.9041      1000
#
#     accuracy                         0.9064     10000
#    macro avg     0.9089    0.9064    0.9066     10000
# weighted avg     0.9089    0.9064    0.9066     10000
